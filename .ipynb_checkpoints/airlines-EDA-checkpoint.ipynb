# %% [markdown]
# # Exploratory Data Analysis: Toussaint Louverture International Airport 2017 - 2020
#
# ##           *   Prediction of Flight Delay

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#anConclusionalysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction <a name="introduction"></a>

# %% [markdown]
# * * Project Description:
#
#
# Air traffic, let's say, air transport has had a truly gigantic effect on the world. It is one of the main drivers of globalization. The commercialization of air transport has made the world a smaller, more connected place. People can easily visit, explore everywhere, every corner, even the remotest corners of the earth, allowing us to connect with cultures far removed from our own. Businesses can grow and connect with each other, and goods can be shipped around the world in a matter of hours, travel around the world has become faster with air travel.
# However, in spite of all the beauty of this means of transport and all its comfort, all is not rosy for the airlines, certainly, air traffic generates big profits, and yet, some problems come to hinder them, such as: airplane accidents, breakdowns or flight delays, etc... Let's look at flight delays, because that's what my study will be based on. What is flight delay? A flight delay is when a plane should leave or arrive at a scheduled time, yet it's delayed or landed later than planned.
# I remember, as a teenager, my mother's sister who was suffering from serious heart disease, had to be sent to Florida for surgery, she had to fly at 9 am, however, the flight was delayed, she couldn't get there in time for her operation, things that quickly became very complicated, but, thanks to her, she was able to do the operation, so, we can see how a simple delay had destabilized her in a critical state. In addition, flight delays can cause the cancellation of meetings, important appointments, gatherings, ceremonies, etc... A company, which constantly has delays in its flights either on departure or arrival, could lose its customers or contracts, because a customer who is not satisfied with its services is almost lost, the loss of customers results in a decrease in revenue. The primary objective of a company is to maximize its profits while satisfying the needs of its customers, a need to move and arrive on time without any problem.
# This project, I have carried out primarily for airlines who wish to optimize their delays in order to better manage their services, with the goal of increasing the confidence and loyalty of their customers. Secondly, this project affects travellers who want to know the best time according to their requirements to travel without expecting too many flight delays.
#
# In my work, I will try to, over a period of about three years :
#     *1) Look at the number of flights made through Haiti that will be divided into delays and non_delays while grouping them by :
#    * A) Company
#    * B) Time
#    * C) Day
#    * D) Month
#    * E) Quarter
#
# 2) With the Learning Machine to predict flight delays

# %%
# Import the required packages
import pandas as pd 
import numpy as np  # linear algebra
import pylab as plt
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ### Adjusting `matplotlib` parameters

# %%
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 40

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# .

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The original data can be seen on the site Toussaint Louverture International Airport (https://www.flightera.net/fr/airport/Port-au-Prince/MTPP/arrival "Toussaint Louverture International Airport"). The selected columns are the same as in this older.
#
# Please refer to [this](https://github.com/Shito3/Airplanes_Analysis/tree/master/Results) notebook on how i scraped the raw data to CSV format.

# %% [markdown]
# ### Read in the data

# %%
# Import Customer Churn Dataset 
url = 'Dataset/airplane_data.csv'
# Read in the data
df = pd.read_csv(url,encoding='utf-8')
# Quick insights into the dataset
df.head()
# Out:
#    Unnamed: 0                                      Date / Statut  \
# 0           0              dim, 01. oct 2017 07:48 EDT A Atterri
# 1           1              dim, 01. oct 2017 07:48 EDT A Atterri
# 2           2              dim, 01. oct 2017 08:00 EDT A Atterri
# 3           3              dim, 01. oct 2017 08:02 EDT A Atterri
# 4           4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                                  Vol  \
# 0          B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 1          B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 2     S6200 Flag of Haiti Sunrise Airways (S6 / KSZ)
# 3        AA1158 AAL1158 American Airlines (AA / AAL)
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                                   De  \
# 0                       Fort Lauderdale (FLL / KFLL)
# 1                       Fort Lauderdale (FLL / KFLL)
# 2                         Santo Domingo (SDQ / MDSD)
# 3                       Fort Lauderdale (FLL / KFLL)
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                    Arrivée Planifiée  \
# 0                                          07:48 EDT
# 1                                          07:48 EDT
# 2                                          08:00 EDT
# 3                                          08:02 EDT
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                               Départ  \
# 0                            06:16 EDT 16 min retard
# 1                            06:16 EDT 16 min retard
# 2                                  07:15 AST à temps
# 3                             06:09 EDT 9 min retard
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                               Arrivé  \
# 0                             07:54 EDT 6 min retard
# 1                             07:54 EDT 6 min retard
# 2                                  08:00 EDT à temps
# 3                               07:46 EDT 16 min tôt
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                                Durée  \
# 0                                             1h 37m
# 1                                             1h 37m
# 2                                                45m
# 3                                             1h 36m
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                           Unnamed: 7  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                           Unnamed: 8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                           Unnamed: 9  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                          Unnamed: 10  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                          Unnamed: 11
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  (adsbygoogle = window.adsbygoogle || []).push(...

# %%
# Let's delete the columns that are not part of the table.
df = df.drop(['Unnamed: 7','Unnamed: 0','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'],axis=1)

# %%
#Let's look at the result now.
df.head()
# Out:
#                                        Date / Statut  \
# 0              dim, 01. oct 2017 07:48 EDT A Atterri
# 1              dim, 01. oct 2017 07:48 EDT A Atterri
# 2              dim, 01. oct 2017 08:00 EDT A Atterri
# 3              dim, 01. oct 2017 08:02 EDT A Atterri
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                                  Vol  \
# 0          B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 1          B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 2     S6200 Flag of Haiti Sunrise Airways (S6 / KSZ)
# 3        AA1158 AAL1158 American Airlines (AA / AAL)
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                                   De  \
# 0                       Fort Lauderdale (FLL / KFLL)
# 1                       Fort Lauderdale (FLL / KFLL)
# 2                         Santo Domingo (SDQ / MDSD)
# 3                       Fort Lauderdale (FLL / KFLL)
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                    Arrivée Planifiée  \
# 0                                          07:48 EDT
# 1                                          07:48 EDT
# 2                                          08:00 EDT
# 3                                          08:02 EDT
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                               Départ  \
# 0                            06:16 EDT 16 min retard
# 1                            06:16 EDT 16 min retard
# 2                                  07:15 AST à temps
# 3                             06:09 EDT 9 min retard
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                               Arrivé  \
# 0                             07:54 EDT 6 min retard
# 1                             07:54 EDT 6 min retard
# 2                                  08:00 EDT à temps
# 3                               07:46 EDT 16 min tôt
# 4  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                                Durée
# 0                                             1h 37m
# 1                                             1h 37m
# 2                                                45m
# 3                                             1h 36m
# 4  (adsbygoogle = window.adsbygoogle || []).push(...

# %%
# Let's check if there are a null values
df[df['Date / Statut'].isna()]
# Out:
#       Date / Statut  Vol   De Arrivée Planifiée Départ Arrivé Durée
# 16              NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 28              NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 52              NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 64              NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 88              NaN  NaN  NaN               NaN    NaN    NaN   NaN
# ...             ...  ...  ...               ...    ...    ...   ...
# 31741           NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 31760           NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 31788           NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 31813           NaN  NaN  NaN               NaN    NaN    NaN   NaN
# 31834           NaN  NaN  NaN               NaN    NaN    NaN   NaN
#
# [1793 rows x 7 columns]

# %%
# Let's sum all a null values
df.isnull().sum() #
# Out:
# Date / Statut        1793
# Vol                  1793
# De                   1793
# Arrivée Planifiée    1793
# Départ               2523
# Arrivé               2523
# Durée                1905
# dtype: int64

# %%
# Delete a missing values
df.dropna(inplace = True)

# %%
df.info() # About DF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29375 entries, 0 to 32003
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date / Statut      29375 non-null  object
#  1   Vol                29375 non-null  object
#  2   De                 29375 non-null  object
#  3   Arrivée Planifiée  29375 non-null  object
#  4   Départ             29375 non-null  object
#  5   Arrivé             29375 non-null  object
#  6   Durée              29375 non-null  object
# dtypes: object(7)
# memory usage: 1.0+ MB

# %%
# Delete the ADS of Google in thd Dataframe
df2 = df[~df['Date / Statut'].str.contains('window.')]

# %%
# Function to separate the of departure and the arrival
def split_date_statut(x,index):
    if 'EDT' in x:
        return x.split('EDT')[index]
    elif 'AST' in x:
         return x.split('AST')[index]
    else:
        return x.split(' ')[index]

# %%
def split_date(x):
    if 'EDT' in x:
        return x.split('EDT')[0]
    elif 'AST' in x:
         return x.split('AST')[0]
    else:
        return x.split(' ')[0]

# %%
# Test
split_date_statut('dim, 01. oct 2017 07:48 EDT A Atterri',0)
# Out:
# 'dim, 01. oct 2017 07:48 '

# %%
# Test2
split_date_statut('dim, 01. oct 2017 07:48 EDT A Atterri',-1)
# Out:
# ' A Atterri'

# %%
# Test3
split_date('07:48 EDT')
# Out:
# '07:48 '

# %%
# Separation of dates and moments
df2['Date'] = df2['Date / Statut'].apply(lambda x: split_date_statut(x,0))
df2['statut'] =df2['Date / Statut'].apply(lambda x: split_date_statut(x,-1))
df2['arrival_planed_time'] =df2['Arrivée Planifiée'].apply(lambda x: split_date(x))
df2['departure_time'] = df2['Départ'].apply(lambda x: split_date_statut(x,0))
df2['departure_status'] = df2['Départ'].apply(lambda x: split_date_statut(x,-1))
df2['arriving_time'] = df2['Arrivé'].apply(lambda x: split_date_statut(x,0))
df2['arriving_status'] = df2['Arrivé'].apply(lambda x: split_date_statut(x,-1))
# Out:
# <ipython-input-16-e84b0ed79bc8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date'] = df2['Date / Statut'].apply(lambda x: split_date_statut(x,0))
# <ipython-input-16-e84b0ed79bc8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['statut'] =df2['Date / Statut'].apply(lambda x: split_date_statut(x,-1))
# <ipython-input-16-e84b0ed79bc8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['arrival_planed_time'] =df2['Arrivée Planifiée'].apply(lambda x: split_date(x))
# <ipython-input-16-e84b0ed79bc8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['departure_time'] = df2['Départ'].apply(lambda x: split_date_statut(x,0))
# <ipython-input-16-e84b0ed79bc8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['departure_status'] = df2['Départ'].apply(lambda x: split_date_statut(x,-1))
# <ipython-input-16-e84b0ed79bc8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['arriving_time'] = df2['Arrivé'].apply(lambda x: split_date_statut(x,0))
# <ipython-input-16-e84b0ed79bc8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['arriving_status'] = df2['Arrivé'].apply(lambda x: split_date_statut(x,-1))

# %%
df2.head()
# Out:
#                            Date / Statut  \
# 0  dim, 01. oct 2017 07:48 EDT A Atterri
# 1  dim, 01. oct 2017 07:48 EDT A Atterri
# 2  dim, 01. oct 2017 08:00 EDT A Atterri
# 3  dim, 01. oct 2017 08:02 EDT A Atterri
# 5  dim, 01. oct 2017 08:02 EDT A Atterri
#
#                                               Vol  \
# 0       B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 1       B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 2  S6200 Flag of Haiti Sunrise Airways (S6 / KSZ)
# 3     AA1158 AAL1158 American Airlines (AA / AAL)
# 5     AA1158 AAL1158 American Airlines (AA / AAL)
#
#                              De Arrivée Planifiée                   Départ  \
# 0  Fort Lauderdale (FLL / KFLL)         07:48 EDT  06:16 EDT 16 min retard
# 1  Fort Lauderdale (FLL / KFLL)         07:48 EDT  06:16 EDT 16 min retard
# 2    Santo Domingo (SDQ / MDSD)         08:00 EDT        07:15 AST à temps
# 3  Fort Lauderdale (FLL / KFLL)         08:02 EDT   06:09 EDT 9 min retard
# 5  Fort Lauderdale (FLL / KFLL)         08:02 EDT   06:09 EDT 9 min retard
#
#                    Arrivé   Durée                      Date      statut  \
# 0  07:54 EDT 6 min retard  1h 37m  dim, 01. oct 2017 07:48    A Atterri
# 1  07:54 EDT 6 min retard  1h 37m  dim, 01. oct 2017 07:48    A Atterri
# 2       08:00 EDT à temps     45m  dim, 01. oct 2017 08:00    A Atterri
# 3    07:46 EDT 16 min tôt  1h 36m  dim, 01. oct 2017 08:02    A Atterri
# 5    07:46 EDT 16 min tôt  1h 36m  dim, 01. oct 2017 08:02    A Atterri
#
#   arrival_planed_time departure_time departure_status arriving_time  \
# 0              07:48          06:16     16 min retard        07:54
# 1              07:48          06:16     16 min retard        07:54
# 2              08:00          07:15           à temps        08:00
# 3              08:02          06:09      9 min retard        07:46
# 5              08:02          06:09      9 min retard        07:46
#
#   arriving_status
# 0    6 min retard
# 1    6 min retard
# 2         à temps
# 3      16 min tôt
# 5      16 min tôt

# %%
# Let's see the result
df2[['statut','Date']]
# Out:
#            statut                      Date
# 0       A Atterri  dim, 01. oct 2017 07:48
# 1       A Atterri  dim, 01. oct 2017 07:48
# 2       A Atterri  dim, 01. oct 2017 08:00
# 3       A Atterri  dim, 01. oct 2017 08:02
# 5       A Atterri  dim, 01. oct 2017 08:02
# ...           ...                       ...
# 31950   A Atterri       sam, 11. avr 11:23
# 31983   A Atterri       jeu, 16. avr 21:45
# 31986   A Atterri       jeu, 16. avr 21:45
# 31996   A Atterri       sam, 18. avr 09:00
# 32000   A Atterri       sam, 18. avr 09:00
#
# [25931 rows x 2 columns]

# %%
# Let's delete the columns that are not necessary for our study.
df2 = df2.drop(['Date / Statut','Arrivée Planifiée','Départ','Arrivé'],axis=1)

# %%
df_final = df2.copy()

# %%
df_final
# Out:
#                                                   Vol  \
# 0           B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 1           B61509 JBU1509 JetBlue Airways (B6 / JBU)
# 2      S6200 Flag of Haiti Sunrise Airways (S6 / KSZ)
# 3         AA1158 AAL1158 American Airlines (AA / AAL)
# 5         AA1158 AAL1158 American Airlines (AA / AAL)
# ...                                               ...
# 31950       NK6450 NKS6450 Spirit Airlines (NK / NKS)
# 31983  M6847 AJT847 Amerijet International (M6 / AJT)
# 31986  M6847 AJT847 Amerijet International (M6 / AJT)
# 31996       B66123 JBU6123 JetBlue Airways (B6 / JBU)
# 32000       B66123 JBU6123 JetBlue Airways (B6 / JBU)
#
#                                  De   Durée                      Date  \
# 0      Fort Lauderdale (FLL / KFLL)  1h 37m  dim, 01. oct 2017 07:48
# 1      Fort Lauderdale (FLL / KFLL)  1h 37m  dim, 01. oct 2017 07:48
# 2        Santo Domingo (SDQ / MDSD)     45m  dim, 01. oct 2017 08:00
# 3      Fort Lauderdale (FLL / KFLL)  1h 36m  dim, 01. oct 2017 08:02
# 5      Fort Lauderdale (FLL / KFLL)  1h 36m  dim, 01. oct 2017 08:02
# ...                             ...     ...                       ...
# 31950  Fort Lauderdale (FLL / KFLL)  2h 25m       sam, 11. avr 11:23
# 31983            Miami (MIA / KMIA)  2h 30m       jeu, 16. avr 21:45
# 31986            Miami (MIA / KMIA)  2h 30m       jeu, 16. avr 21:45
# 31996  Fort Lauderdale (FLL / KFLL)  5h 57m       sam, 18. avr 09:00
# 32000  Fort Lauderdale (FLL / KFLL)  5h 57m       sam, 18. avr 09:00
#
#            statut arrival_planed_time departure_time departure_status  \
# 0       A Atterri              07:48          06:16     16 min retard
# 1       A Atterri              07:48          06:16     16 min retard
# 2       A Atterri              08:00          07:15           à temps
# 3       A Atterri              08:02          06:09      9 min retard
# 5       A Atterri              08:02          06:09      9 min retard
# ...           ...                 ...            ...              ...
# 31950   A Atterri              11:23          09:00          planifié
# 31983   A Atterri              21:45          19:15          planifié
# 31986   A Atterri              21:45          19:15          planifié
# 31996   A Atterri              09:00          06:40          planifié
# 32000   A Atterri              09:00          06:40          planifié
#
#       arriving_time     arriving_status
# 0            07:54         6 min retard
# 1            07:54         6 min retard
# 2            08:00              à temps
# 3            07:46           16 min tôt
# 5            07:46           16 min tôt
# ...             ...                 ...
# 31950        11:25         2 min retard
# 31983        21:45             planifié
# 31986        21:45             planifié
# 31996        12:37    3 h 37 min retard
# 32000        12:37    3 h 37 min retard
#
# [25931 rows x 10 columns]

# %%
df_final[df_final.Date.str.contains('fev 2018')]
# Out:
# Empty DataFrame
# Columns: [Vol, De, Durée, Date, statut, arrival_planed_time, departure_time, departure_status, arriving_time, arriving_status]
# Index: []

# %%
# Function dates conversion in text format
def date_convert1(x):
    map_month ={'jan':'01','fev':'02','mars':'03','avr':'04','mai':'05','juin':'06','juil':'07','août':'08','sept':'09','oct':'10','nov':'11','déc':'12'}
    val= x.split(' ')
    date_text =""
    lenght = len(val)
    print(val)
    if lenght == 4:
        old_value = val[3]
        val[3] = 2020
        val.append(old_value)
    
    if lenght >= 4:
        day =val[1].split('.')
        if len(day) >0:
            val[1] = day[0]
        year = str(val[3]).split(':')
        if len(year) > 1:
            val[3] = 2020
        date_text =str(map_month[val[2]]) + '/'+str(val[1])+ '/'+str(val[3])
        
    return date_text

# %%
# test of the function
date_convert1('dim, 08. mars 08:44')
# Out:
# ['dim,', '08.', 'mars', '08:44']
# '03/08/2020'

# %%
# Function application
df_final['date_text'] = df_final['Date'].apply(lambda x: date_convert1(x))
# Out:
# ['dim,', '01.', 'oct', '2017', '07:48', '']
# ['dim,', '01.', 'oct', '2017', '07:48', '']
# ['dim,', '01.', 'oct', '2017', '08:00', '']
# ['dim,', '01.', 'oct', '2017', '08:02', '']
# ['dim,', '01.', 'oct', '2017', '08:02', '']
# ['dim,', '01.', 'oct', '2017', '08:17', '']
# ['dim,', '01.', 'oct', '2017', '08:30', '']
# ['dim,', '01.', 'oct', '2017', '09:00', '']
# ['dim,', '01.', 'oct', '2017', '09:11', '']
# ['dim,', '01.', 'oct', '2017', '09:11', '']
# ['dim,', '01.', 'oct', '2017', '09:20', '']
# ['dim,', '01.', 'oct', '2017', '09:20', '']
# ['dim,', '01.', 'oct', '2017', '11:09', '']
# ['dim,', '01.', 'oct', '2017', '11:09', '']
# ['dim,', '01.', 'oct', '2017', '11:10', '']
# ['dim,', '01.', 'oct', '2017', '11:10', '']
# ['dim,', '01.', 'oct', '2017', '12:59', '']
# ['dim,', '01.', 'oct', '2017', '12:59', '']
# ['dim,', '01.', 'oct', '2017', '13:10', '']
# ['dim,', '01.', 'oct', '2017', '13:15', '']
# ['dim,', '01.', 'oct', '2017', '13:15', '']
# ['dim,', '01.', 'oct', '2017', '13:15', '']
# ['dim,', '01.', 'oct', '2017', '13:30', '']
# ['dim,', '01.', 'oct', '2017', '14:00', '']
# ['dim,', '01.', 'oct', '2017', '14:35', '']
# ['dim,', '01.', 'oct', '2017', '14:35', '']
# ['dim,', '01.', 'oct', '2017', '15:52', '']
# ['dim,', '01.', 'oct', '2017', '15:52', '']
# ['dim,', '01.', 'oct', '2017', '16:35', '']
# ['dim,', '01.', 'oct', '2017', '16:35', '']
# ['lun,', '02.', 'oct', '2017', '07:48', '']
# ['lun,', '02.', 'oct', '2017', '07:48', '']
# ['lun,', '02.', 'oct', '2017', '08:00', '']
# ['lun,', '02.', 'oct', '2017', '08:02', '']
# ['lun,', '02.', 'oct', '2017', '08:02', '']
# ['lun,', '02.', 'oct', '2017', '08:17', '']
# ['lun,', '02.', 'oct', '2017', '08:30', '']
# ['lun,', '02.', 'oct', '2017', '09:00', '']
# ['lun,', '02.', 'oct', '2017', '09:11', '']
# ['lun,', '02.', 'oct', '2017', '09:11', '']
# ['lun,', '02.', 'oct', '2017', '09:20', '']
# ['lun,', '02.', 'oct', '2017', '09:20', '']
# ['lun,', '02.', 'oct', '2017', '10:35', '']
# ['lun,', '02.', 'oct', '2017', '11:00', '']
# ['lun,', '02.', 'oct', '2017', '11:00', '']
# ['lun,', '02.', 'oct', '2017', '11:00', '']
# ['lun,', '02.', 'oct', '2017', '11:00', '']
# ['lun,', '02.', 'oct', '2017', '11:09', '']
# ['lun,', '02.', 'oct', '2017', '11:09', '']
# ['lun,', '02.', 'oct', '2017', '11:10', '']
# ['lun,', '02.', 'oct', '2017', '11:10', '']
# ['lun,', '02.', 'oct', '2017', '11:50', '']
# ['lun,', '02.', 'oct', '2017', '11:50', '']
# ['lun,', '02.', 'oct', '2017', '11:55', '']
# ['lun,', '02.', 'oct', '2017', '12:59', '']
# ['lun,', '02.', 'oct', '2017', '12:59', '']
# ['lun,', '02.', 'oct', '2017', '13:30', '']
# ['lun,', '02.', 'oct', '2017', '14:35', '']
# ['mar,', '03.', 'oct', '2017', '07:48', '']
# ['mar,', '03.', 'oct', '2017', '07:48', '']
# ['mar,', '03.', 'oct', '2017', '08:02', '']
# ['mar,', '03.', 'oct', '2017', '08:02', '']
# ['mar,', '03.', 'oct', '2017', '08:17', '']
# ['mar,', '03.', 'oct', '2017', '08:30', '']
# ['mar,', '03.', 'oct', '2017', '09:00', '']
# ['mar,', '03.', 'oct', '2017', '09:20', '']
# ['mar,', '03.', 'oct', '2017', '09:20', '']
# ['mar,', '03.', 'oct', '2017', '10:30', '']
# ['mar,', '03.', 'oct', '2017', '10:35', '']
# ['mar,', '03.', 'oct', '2017', '11:00', '']
# ['mar,', '03.', 'oct', '2017', '11:00', '']
# ['mar,', '03.', 'oct', '2017', '11:00', '']
# ['mar,', '03.', 'oct', '2017', '11:09', '']
# ['mar,', '03.', 'oct', '2017', '11:09', '']
# ['mar,', '03.', 'oct', '2017', '11:10', '']
# ['mar,', '03.', 'oct', '2017', '11:10', '']
# ['mar,', '03.', 'oct', '2017', '12:07', '']
# ['mar,', '03.', 'oct', '2017', '12:07', '']
# ['mar,', '03.', 'oct', '2017', '12:20', '']
# ['mar,', '03.', 'oct', '2017', '12:20', '']
# ['mar,', '03.', 'oct', '2017', '12:59', '']
# ['mar,', '03.', 'oct', '2017', '12:59', '']
# ['mar,', '03.', 'oct', '2017', '13:00', '']
# ['mar,', '03.', 'oct', '2017', '13:05', '']
# ['mar,', '03.', 'oct', '2017', '13:15', '']
# ['mar,', '03.', 'oct', '2017', '13:30', '']
# ['mar,', '03.', 'oct', '2017', '13:45', '']
# ['mar,', '03.', 'oct', '2017', '13:45', '']
# ['mer,', '04.', 'oct', '2017', '07:00', '']
# ['mer,', '04.', 'oct', '2017', '07:00', '']
# ['mer,', '04.', 'oct', '2017', '07:48', '']
# ['mer,', '04.', 'oct', '2017', '07:48', '']
# ['mer,', '04.', 'oct', '2017', '08:02', '']
# ['mer,', '04.', 'oct', '2017', '08:02', '']
# ['mer,', '04.', 'oct', '2017', '08:30', '']
# ['mer,', '04.', 'oct', '2017', '09:00', '']
# ['mer,', '04.', 'oct', '2017', '09:00', '']
# ['mer,', '04.', 'oct', '2017', '09:20', '']
# ['mer,', '04.', 'oct', '2017', '09:20', '']
# ['mer,', '04.', 'oct', '2017', '10:30', '']
# ['mer,', '04.', 'oct', '2017', '11:00', '']
# ['mer,', '04.', 'oct', '2017', '11:00', '']
# ['mer,', '04.', 'oct', '2017', '11:09', '']
# ['mer,', '04.', 'oct', '2017', '11:09', '']
# ['mer,', '04.', 'oct', '2017', '11:10', '']
# ['mer,', '04.', 'oct', '2017', '11:10', '']
# ['mer,', '04.', 'oct', '2017', '12:07', '']
# ['mer,', '04.', 'oct', '2017', '12:07', '']
# ['mer,', '04.', 'oct', '2017', '12:15', '']
# ['mer,', '04.', 'oct', '2017', '12:59', '']
# ['mer,', '04.', 'oct', '2017', '12:59', '']
# ['mer,', '04.', 'oct', '2017', '13:15', '']
# ['mer,', '04.', 'oct', '2017', '13:30', '']
# ['mer,', '04.', 'oct', '2017', '14:30', '']
# ['mer,', '04.', 'oct', '2017', '14:30', '']
# ['mer,', '04.', 'oct', '2017', '14:35', '']
# ['mer,', '04.', 'oct', '2017', '14:35', '']
# ['mer,', '04.', 'oct', '2017', '15:40', '']
# ['jeu,', '05.', 'oct', '2017', '07:48', '']
# ['jeu,', '05.', 'oct', '2017', '07:48', '']
# ['jeu,', '05.', 'oct', '2017', '08:00', '']
# ['jeu,', '05.', 'oct', '2017', '08:02', '']
# ['jeu,', '05.', 'oct', '2017', '08:02', '']
# ['jeu,', '05.', 'oct', '2017', '08:30', '']
# ['jeu,', '05.', 'oct', '2017', '09:00', '']
# ['jeu,', '05.', 'oct', '2017', '09:00', '']
# ['jeu,', '05.', 'oct', '2017', '09:11', '']
# ['jeu,', '05.', 'oct', '2017', '09:11', '']
# ['jeu,', '05.', 'oct', '2017', '09:20', '']
# ['jeu,', '05.', 'oct', '2017', '09:20', '']
# ['jeu,', '05.', 'oct', '2017', '10:30', '']
# ['jeu,', '05.', 'oct', '2017', '11:00', '']
# ['jeu,', '05.', 'oct', '2017', '11:00', '']
# ['jeu,', '05.', 'oct', '2017', '11:00', '']
# ['jeu,', '05.', 'oct', '2017', '11:09', '']
# ['jeu,', '05.', 'oct', '2017', '11:09', '']
# ['jeu,', '05.', 'oct', '2017', '11:20', '']
# ['jeu,', '05.', 'oct', '2017', '11:20', '']
# ['jeu,', '05.', 'oct', '2017', '12:07', '']
# ['jeu,', '05.', 'oct', '2017', '12:07', '']
# ['jeu,', '05.', 'oct', '2017', '12:56', '']
# ['jeu,', '05.', 'oct', '2017', '12:56', '']
# ['jeu,', '05.', 'oct', '2017', '13:30', '']
# ['jeu,', '05.', 'oct', '2017', '14:00', '']
# ['jeu,', '05.', 'oct', '2017', '14:35', '']
# ['jeu,', '05.', 'oct', '2017', '14:35', '']
# ['jeu,', '05.', 'oct', '2017', '15:10', '']
# ['jeu,', '05.', 'oct', '2017', '15:52', '']
# ['ven,', '06.', 'oct', '2017', '07:48', '']
# ['ven,', '06.', 'oct', '2017', '07:48', '']
# ['ven,', '06.', 'oct', '2017', '08:00', '']
# ['ven,', '06.', 'oct', '2017', '08:02', '']
# ['ven,', '06.', 'oct', '2017', '08:02', '']
# ['ven,', '06.', 'oct', '2017', '08:11', '']
# ['ven,', '06.', 'oct', '2017', '08:11', '']
# ['ven,', '06.', 'oct', '2017', '08:17', '']
# ['ven,', '06.', 'oct', '2017', '08:30', '']
# ['ven,', '06.', 'oct', '2017', '09:00', '']
# ['ven,', '06.', 'oct', '2017', '09:11', '']
# ['ven,', '06.', 'oct', '2017', '09:11', '']
# ['ven,', '06.', 'oct', '2017', '09:20', '']
# ['ven,', '06.', 'oct', '2017', '09:20', '']
# ['ven,', '06.', 'oct', '2017', '10:30', '']
# ['ven,', '06.', 'oct', '2017', '10:30', '']
# ['ven,', '06.', 'oct', '2017', '11:00', '']
# ['ven,', '06.', 'oct', '2017', '11:00', '']
# ['ven,', '06.', 'oct', '2017', '11:00', '']
# ['ven,', '06.', 'oct', '2017', '11:00', '']
# ['ven,', '06.', 'oct', '2017', '11:09', '']
# ['ven,', '06.', 'oct', '2017', '11:09', '']
# ['ven,', '06.', 'oct', '2017', '11:20', '']
# ['ven,', '06.', 'oct', '2017', '11:20', '']
# ['ven,', '06.', 'oct', '2017', '11:50', '']
# ['ven,', '06.', 'oct', '2017', '12:50', '']
# ['ven,', '06.', 'oct', '2017', '12:56', '']
# ['ven,', '06.', 'oct', '2017', '12:56', '']
# ['ven,', '06.', 'oct', '2017', '12:58', '']
# ['sam,', '07.', 'oct', '2017', '07:00', '']
# ['sam,', '07.', 'oct', '2017', '07:00', '']
# ['sam,', '07.', 'oct', '2017', '07:48', '']
# ['sam,', '07.', 'oct', '2017', '07:48', '']
# ['sam,', '07.', 'oct', '2017', '08:02', '']
# ['sam,', '07.', 'oct', '2017', '08:02', '']
# ['sam,', '07.', 'oct', '2017', '08:17', '']
# ['sam,', '07.', 'oct', '2017', '08:17', '']
# ['sam,', '07.', 'oct', '2017', '08:30', '']
# ['sam,', '07.', 'oct', '2017', '08:30', '']
# ['sam,', '07.', 'oct', '2017', '09:00', '']
# ['sam,', '07.', 'oct', '2017', '09:00', '']
# ['sam,', '07.', 'oct', '2017', '09:11', '']
# ['sam,', '07.', 'oct', '2017', '09:11', '']
# ['sam,', '07.', 'oct', '2017', '09:20', '']
# ['sam,', '07.', 'oct', '2017', '09:20', '']
# ['sam,', '07.', 'oct', '2017', '10:35', '']
# ['sam,', '07.', 'oct', '2017', '10:35', '']
# ['sam,', '07.', 'oct', '2017', '11:00', '']
# ['sam,', '07.', 'oct', '2017', '11:00', '']
# ['sam,', '07.', 'oct', '2017', '11:00', '']
# ['sam,', '07.', 'oct', '2017', '11:09', '']
# ['sam,', '07.', 'oct', '2017', '11:09', '']
# ['sam,', '07.', 'oct', '2017', '11:20', '']
# ['sam,', '07.', 'oct', '2017', '11:20', '']
# ['sam,', '07.', 'oct', '2017', '12:00', '']
# ['sam,', '07.', 'oct', '2017', '12:07', '']
# ['sam,', '07.', 'oct', '2017', '12:07', '']
# ['sam,', '07.', 'oct', '2017', '12:15', '']
# ['sam,', '07.', 'oct', '2017', '12:56', '']
# ['dim,', '08.', 'oct', '2017', '07:48', '']
# ['dim,', '08.', 'oct', '2017', '07:48', '']
# ['dim,', '08.', 'oct', '2017', '08:00', '']
# ['dim,', '08.', 'oct', '2017', '08:00', '']
# ['dim,', '08.', 'oct', '2017', '08:02', '']
# ['dim,', '08.', 'oct', '2017', '08:02', '']
# ['dim,', '08.', 'oct', '2017', '08:17', '']
# ['dim,', '08.', 'oct', '2017', '08:17', '']
# ['dim,', '08.', 'oct', '2017', '08:30', '']
# ['dim,', '08.', 'oct', '2017', '08:30', '']
# ['dim,', '08.', 'oct', '2017', '09:00', '']
# ['dim,', '08.', 'oct', '2017', '09:00', '']
# ['dim,', '08.', 'oct', '2017', '09:11', '']
# ['dim,', '08.', 'oct', '2017', '09:11', '']
# ['dim,', '08.', 'oct', '2017', '09:20', '']
# ['dim,', '08.', 'oct', '2017', '09:20', '']
# ['dim,', '08.', 'oct', '2017', '11:09', '']
# ['dim,', '08.', 'oct', '2017', '11:09', '']
# ['dim,', '08.', 'oct', '2017', '11:20', '']
# ['dim,', '08.', 'oct', '2017', '11:20', '']
# ['dim,', '08.', 'oct', '2017', '11:52', '']
# ['dim,', '08.', 'oct', '2017', '12:56', '']
# ['dim,', '08.', 'oct', '2017', '12:56', '']
# ['dim,', '08.', 'oct', '2017', '13:10', '']
# ['dim,', '08.', 'oct', '2017', '13:10', '']
# ['dim,', '08.', 'oct', '2017', '13:15', '']
# ['dim,', '08.', 'oct', '2017', '13:15', '']
# ['dim,', '08.', 'oct', '2017', '13:15', '']
# ['dim,', '08.', 'oct', '2017', '13:15', '']
# ['dim,', '08.', 'oct', '2017', '13:30', '']
# ['lun,', '09.', 'oct', '2017', '07:48', '']
# ['lun,', '09.', 'oct', '2017', '08:00', '']
# ['lun,', '09.', 'oct', '2017', '08:02', '']
# ['lun,', '09.', 'oct', '2017', '08:17', '']
# ['lun,', '09.', 'oct', '2017', '08:30', '']
# ['lun,', '09.', 'oct', '2017', '09:00', '']
# ['lun,', '09.', 'oct', '2017', '09:11', '']
# ['lun,', '09.', 'oct', '2017', '09:20', '']
# ['lun,', '09.', 'oct', '2017', '10:00', '']
# ['lun,', '09.', 'oct', '2017', '10:35', '']
# ['lun,', '09.', 'oct', '2017', '11:00', '']
# ['lun,', '09.', 'oct', '2017', '11:00', '']
# ['lun,', '09.', 'oct', '2017', '11:09', '']
# ['lun,', '09.', 'oct', '2017', '11:20', '']
# ['lun,', '09.', 'oct', '2017', '11:29', '']
# ['lun,', '09.', 'oct', '2017', '11:50', '']
# ['lun,', '09.', 'oct', '2017', '12:50', '']
# ['lun,', '09.', 'oct', '2017', '12:56', '']
# ['lun,', '09.', 'oct', '2017', '13:30', '']
# ['lun,', '09.', 'oct', '2017', '14:35', '']
# ['lun,', '09.', 'oct', '2017', '15:52', '']
# ['lun,', '09.', 'oct', '2017', '16:35', '']
# ['lun,', '09.', 'oct', '2017', '16:45', '']
# ['lun,', '09.', 'oct', '2017', '17:17', '']
# ['lun,', '09.', 'oct', '2017', '17:39', '']
# ['lun,', '09.', 'oct', '2017', '17:50', '']
# ['lun,', '09.', 'oct', '2017', '18:00', '']
# ['lun,', '09.', 'oct', '2017', '18:30', '']
# ['mar,', '10.', 'oct', '2017', '07:48', '']
# ['mar,', '10.', 'oct', '2017', '08:02', '']
# ['mar,', '10.', 'oct', '2017', '07:48', '']
# ['mar,', '10.', 'oct', '2017', '08:02', '']
# ['mar,', '10.', 'oct', '2017', '08:17', '']
# ['mar,', '10.', 'oct', '2017', '08:30', '']
# ['mar,', '10.', 'oct', '2017', '09:00', '']
# ['mar,', '10.', 'oct', '2017', '09:20', '']
# ['mar,', '10.', 'oct', '2017', '10:35', '']
# ['mar,', '10.', 'oct', '2017', '11:00', '']
# ['mar,', '10.', 'oct', '2017', '11:00', '']
# ['mar,', '10.', 'oct', '2017', '11:09', '']
# ['mar,', '10.', 'oct', '2017', '11:20', '']
# ['mar,', '10.', 'oct', '2017', '12:07', '']
# ['mar,', '10.', 'oct', '2017', '12:56', '']
# ['mar,', '10.', 'oct', '2017', '12:56', '']
# ['mar,', '10.', 'oct', '2017', '13:05', '']
# ['mar,', '10.', 'oct', '2017', '13:30', '']
# ['mar,', '10.', 'oct', '2017', '13:30', '']
# ['mar,', '10.', 'oct', '2017', '13:30', '']
# ['mar,', '10.', 'oct', '2017', '13:45', '']
# ['mar,', '10.', 'oct', '2017', '13:50', '']
# ['mar,', '10.', 'oct', '2017', '14:50', '']
# ['mar,', '10.', 'oct', '2017', '15:39', '']
# ['mar,', '10.', 'oct', '2017', '15:52', '']
# ['mar,', '10.', 'oct', '2017', '16:35', '']
# ['mar,', '10.', 'oct', '2017', '16:45', '']
# ['mar,', '10.', 'oct', '2017', '17:17', '']
# ['mar,', '10.', 'oct', '2017', '18:00', '']
# ['mar,', '10.', 'oct', '2017', '18:00', '']
# ['mar,', '10.', 'oct', '2017', '19:00', '']
# ['mer,', '11.', 'oct', '2017', '07:00', '']
# ['mer,', '11.', 'oct', '2017', '07:48', '']
# ['mer,', '11.', 'oct', '2017', '08:02', '']
# ['mer,', '11.', 'oct', '2017', '08:17', '']
# ['mer,', '11.', 'oct', '2017', '08:30', '']
# ['mer,', '11.', 'oct', '2017', '09:00', '']
# ['mer,', '11.', 'oct', '2017', '09:20', '']
# ['mer,', '11.', 'oct', '2017', '10:35', '']
# ['mer,', '11.', 'oct', '2017', '11:00', '']
# ['mer,', '11.', 'oct', '2017', '11:09', '']
# ['mer,', '11.', 'oct', '2017', '11:20', '']
# ['mer,', '11.', 'oct', '2017', '12:07', '']
# ['mer,', '11.', 'oct', '2017', '12:15', '']
# ['mer,', '11.', 'oct', '2017', '12:56', '']
# ['mer,', '11.', 'oct', '2017', '12:56', '']
# ['mer,', '11.', 'oct', '2017', '13:15', '']
# ['mer,', '11.', 'oct', '2017', '13:30', '']
# ['mer,', '11.', 'oct', '2017', '13:35', '']
# ['mer,', '11.', 'oct', '2017', '14:30', '']
# ['mer,', '11.', 'oct', '2017', '14:35', '']
# ['mer,', '11.', 'oct', '2017', '15:52', '']
# ['mer,', '11.', 'oct', '2017', '15:55', '']
# ['mer,', '11.', 'oct', '2017', '16:45', '']
# ['mer,', '11.', 'oct', '2017', '17:17', '']
# ['mer,', '11.', 'oct', '2017', '17:50', '']
# ['mer,', '11.', 'oct', '2017', '18:00', '']
# ['mer,', '11.', 'oct', '2017', '18:20', '']
# ['jeu,', '12.', 'oct', '2017', '07:48', '']
# ['jeu,', '12.', 'oct', '2017', '08:00', '']
# ['jeu,', '12.', 'oct', '2017', '08:02', '']
# ['jeu,', '12.', 'oct', '2017', '07:48', '']
# ['jeu,', '12.', 'oct', '2017', '08:00', '']
# ['jeu,', '12.', 'oct', '2017', '08:02', '']
# ['jeu,', '12.', 'oct', '2017', '08:17', '']
# ['jeu,', '12.', 'oct', '2017', '08:30', '']
# ['jeu,', '12.', 'oct', '2017', '09:00', '']
# ['jeu,', '12.', 'oct', '2017', '09:11', '']
# ['jeu,', '12.', 'oct', '2017', '09:20', '']
# ['jeu,', '12.', 'oct', '2017', '10:35', '']
# ['jeu,', '12.', 'oct', '2017', '11:00', '']
# ['jeu,', '12.', 'oct', '2017', '11:00', '']
# ['jeu,', '12.', 'oct', '2017', '11:09', '']
# ['jeu,', '12.', 'oct', '2017', '11:20', '']
# ['jeu,', '12.', 'oct', '2017', '12:07', '']
# ['jeu,', '12.', 'oct', '2017', '12:56', '']
# ['jeu,', '12.', 'oct', '2017', '12:59', '']
# ['jeu,', '12.', 'oct', '2017', '13:30', '']
# ['jeu,', '12.', 'oct', '2017', '14:00', '']
# ['jeu,', '12.', 'oct', '2017', '14:35', '']
# ['jeu,', '12.', 'oct', '2017', '15:10', '']
# ['jeu,', '12.', 'oct', '2017', '15:52', '']
# ['jeu,', '12.', 'oct', '2017', '16:35', '']
# ['jeu,', '12.', 'oct', '2017', '16:45', '']
# ['jeu,', '12.', 'oct', '2017', '17:17', '']
# ['jeu,', '12.', 'oct', '2017', '17:39', '']
# ['jeu,', '12.', 'oct', '2017', '18:00', '']
# ['jeu,', '12.', 'oct', '2017', '18:00', '']
# ['jeu,', '12.', 'oct', '2017', '18:20', '']
# ['ven,', '13.', 'oct', '2017', '07:48', '']
# ['ven,', '13.', 'oct', '2017', '08:00', '']
# ['ven,', '13.', 'oct', '2017', '07:48', '']
# ['ven,', '13.', 'oct', '2017', '08:00', '']
# ['ven,', '13.', 'oct', '2017', '08:02', '']
# ['ven,', '13.', 'oct', '2017', '08:17', '']
# ['ven,', '13.', 'oct', '2017', '08:30', '']
# ['ven,', '13.', 'oct', '2017', '09:00', '']
# ['ven,', '13.', 'oct', '2017', '09:11', '']
# ['ven,', '13.', 'oct', '2017', '09:20', '']
# ['ven,', '13.', 'oct', '2017', '10:35', '']
# ['ven,', '13.', 'oct', '2017', '11:00', '']
# ['ven,', '13.', 'oct', '2017', '11:00', '']
# ['ven,', '13.', 'oct', '2017', '11:09', '']
# ['ven,', '13.', 'oct', '2017', '11:20', '']
# ['ven,', '13.', 'oct', '2017', '11:50', '']
# ['ven,', '13.', 'oct', '2017', '12:50', '']
# ['ven,', '13.', 'oct', '2017', '12:56', '']
# ['ven,', '13.', 'oct', '2017', '13:10', '']
# ['ven,', '13.', 'oct', '2017', '13:30', '']
# ['ven,', '13.', 'oct', '2017', '14:35', '']
# ['ven,', '13.', 'oct', '2017', '15:52', '']
# ['ven,', '13.', 'oct', '2017', '16:35', '']
# ['ven,', '13.', 'oct', '2017', '16:45', '']
# ['ven,', '13.', 'oct', '2017', '17:17', '']
# ['ven,', '13.', 'oct', '2017', '17:39', '']
# ['ven,', '13.', 'oct', '2017', '18:00', '']
# ['ven,', '13.', 'oct', '2017', '18:20', '']
# ['ven,', '13.', 'oct', '2017', '19:00', '']
# ['sam,', '14.', 'oct', '2017', '07:00', '']
# ['sam,', '14.', 'oct', '2017', '07:48', '']
# ['sam,', '14.', 'oct', '2017', '08:02', '']
# ['sam,', '14.', 'oct', '2017', '07:00', '']
# ['sam,', '14.', 'oct', '2017', '07:48', '']
# ['sam,', '14.', 'oct', '2017', '08:02', '']
# ['sam,', '14.', 'oct', '2017', '09:11', '']
# ['sam,', '14.', 'oct', '2017', '09:20', '']
# ['sam,', '14.', 'oct', '2017', '10:35', '']
# ['sam,', '14.', 'oct', '2017', '11:00', '']
# ['sam,', '14.', 'oct', '2017', '11:09', '']
# ['sam,', '14.', 'oct', '2017', '11:20', '']
# ['sam,', '14.', 'oct', '2017', '11:54', '']
# ['sam,', '14.', 'oct', '2017', '12:00', '']
# ['sam,', '14.', 'oct', '2017', '12:07', '']
# ['sam,', '14.', 'oct', '2017', '12:15', '']
# ['sam,', '14.', 'oct', '2017', '12:21', '']
# ['sam,', '14.', 'oct', '2017', '12:56', '']
# ['sam,', '14.', 'oct', '2017', '13:00', '']
# ['sam,', '14.', 'oct', '2017', '13:10', '']
# ['sam,', '14.', 'oct', '2017', '13:50', '']
# ['sam,', '14.', 'oct', '2017', '14:35', '']
# ['sam,', '14.', 'oct', '2017', '15:52', '']
# ['sam,', '14.', 'oct', '2017', '16:35', '']
# ['sam,', '14.', 'oct', '2017', '16:45', '']
# ['sam,', '14.', 'oct', '2017', '17:17', '']
# ['sam,', '14.', 'oct', '2017', '17:39', '']
# ['sam,', '14.', 'oct', '2017', '17:45', '']
# ['sam,', '14.', 'oct', '2017', '17:50', '']
# ['sam,', '14.', 'oct', '2017', '18:00', '']
# ['dim,', '15.', 'oct', '2017', '07:48', '']
# ['dim,', '15.', 'oct', '2017', '08:00', '']
# ['dim,', '15.', 'oct', '2017', '07:48', '']
# ['dim,', '15.', 'oct', '2017', '08:00', '']
# ['dim,', '15.', 'oct', '2017', '08:02', '']
# ['dim,', '15.', 'oct', '2017', '08:17', '']
# ['dim,', '15.', 'oct', '2017', '08:30', '']
# ['dim,', '15.', 'oct', '2017', '09:00', '']
# ['dim,', '15.', 'oct', '2017', '09:11', '']
# ['dim,', '15.', 'oct', '2017', '09:20', '']
# ['dim,', '15.', 'oct', '2017', '11:09', '']
# ['dim,', '15.', 'oct', '2017', '11:20', '']
# ['dim,', '15.', 'oct', '2017', '12:56', '']
# ['dim,', '15.', 'oct', '2017', '13:10', '']
# ['dim,', '15.', 'oct', '2017', '13:15', '']
# ['dim,', '15.', 'oct', '2017', '13:15', '']
# ['dim,', '15.', 'oct', '2017', '13:30', '']
# ['dim,', '15.', 'oct', '2017', '14:00', '']
# ['dim,', '15.', 'oct', '2017', '14:35', '']
# ['dim,', '15.', 'oct', '2017', '15:52', '']
# ['dim,', '15.', 'oct', '2017', '16:35', '']
# ['dim,', '15.', 'oct', '2017', '16:45', '']
# ['dim,', '15.', 'oct', '2017', '17:17', '']
# ['dim,', '15.', 'oct', '2017', '17:39', '']
# ['dim,', '15.', 'oct', '2017', '18:00', '']
# ['dim,', '15.', 'oct', '2017', '18:00', '']
# ['dim,', '15.', 'oct', '2017', '18:20', '']
# ['dim,', '15.', 'oct', '2017', '19:45', '']
# ['dim,', '15.', 'oct', '2017', '19:45', '']
# ['lun,', '16.', 'oct', '2017', '07:48', '']
# ['lun,', '16.', 'oct', '2017', '08:00', '']
# ['lun,', '16.', 'oct', '2017', '08:02', '']
# ['lun,', '16.', 'oct', '2017', '07:48', '']
# ['lun,', '16.', 'oct', '2017', '08:00', '']
# ['lun,', '16.', 'oct', '2017', '08:02', '']
# ['lun,', '16.', 'oct', '2017', '08:17', '']
# ['lun,', '16.', 'oct', '2017', '08:30', '']
# ['lun,', '16.', 'oct', '2017', '09:00', '']
# ['lun,', '16.', 'oct', '2017', '09:11', '']
# ['lun,', '16.', 'oct', '2017', '09:20', '']
# ['lun,', '16.', 'oct', '2017', '10:35', '']
# ['lun,', '16.', 'oct', '2017', '11:00', '']
# ['lun,', '16.', 'oct', '2017', '11:00', '']
# ['lun,', '16.', 'oct', '2017', '11:09', '']
# ['lun,', '16.', 'oct', '2017', '11:20', '']
# ['lun,', '16.', 'oct', '2017', '11:27', '']
# ['lun,', '16.', 'oct', '2017', '11:50', '']
# ['lun,', '16.', 'oct', '2017', '12:50', '']
# ['lun,', '16.', 'oct', '2017', '12:56', '']
# ['lun,', '16.', 'oct', '2017', '13:30', '']
# ['lun,', '16.', 'oct', '2017', '14:35', '']
# ['lun,', '16.', 'oct', '2017', '15:52', '']
# ['lun,', '16.', 'oct', '2017', '16:35', '']
# ['lun,', '16.', 'oct', '2017', '16:45', '']
# ['lun,', '16.', 'oct', '2017', '17:17', '']
# ['lun,', '16.', 'oct', '2017', '17:39', '']
# ['lun,', '16.', 'oct', '2017', '17:50', '']
# ['lun,', '16.', 'oct', '2017', '18:00', '']
# ['lun,', '16.', 'oct', '2017', '18:20', '']
# ['mar,', '17.', 'oct', '2017', '07:48', '']
# ['mar,', '17.', 'oct', '2017', '08:02', '']
# ['mar,', '17.', 'oct', '2017', '08:17', '']
# ['mar,', '17.', 'oct', '2017', '07:48', '']
# ['mar,', '17.', 'oct', '2017', '08:02', '']
# ['mar,', '17.', 'oct', '2017', '08:17', '']
# ['mar,', '17.', 'oct', '2017', '08:30', '']
# ['mar,', '17.', 'oct', '2017', '09:00', '']
# ['mar,', '17.', 'oct', '2017', '09:20', '']
# ['mar,', '17.', 'oct', '2017', '10:35', '']
# ['mar,', '17.', 'oct', '2017', '11:00', '']
# ['mar,', '17.', 'oct', '2017', '11:09', '']
# ['mar,', '17.', 'oct', '2017', '11:20', '']
# ['mar,', '17.', 'oct', '2017', '12:00', '']
# ['mar,', '17.', 'oct', '2017', '12:07', '']
# ['mar,', '17.', 'oct', '2017', '12:10', '']
# ['mar,', '17.', 'oct', '2017', '12:52', '']
# ['mar,', '17.', 'oct', '2017', '12:56', '']
# ['mar,', '17.', 'oct', '2017', '13:05', '']
# ['mar,', '17.', 'oct', '2017', '13:30', '']
# ['mar,', '17.', 'oct', '2017', '13:30', '']
# ['mar,', '17.', 'oct', '2017', '13:30', '']
# ['mar,', '17.', 'oct', '2017', '13:45', '']
# ['mar,', '17.', 'oct', '2017', '13:50', '']
# ['mar,', '17.', 'oct', '2017', '15:10', '']
# ['mar,', '17.', 'oct', '2017', '15:52', '']
# ['mar,', '17.', 'oct', '2017', '16:35', '']
# ['mar,', '17.', 'oct', '2017', '16:45', '']
# ['mar,', '17.', 'oct', '2017', '16:52', '']
# ['mar,', '17.', 'oct', '2017', '17:17', '']
# ['mar,', '17.', 'oct', '2017', '18:00', '']
# ['mar,', '17.', 'oct', '2017', '18:00', '']
# ['mer,', '18.', 'oct', '2017', '07:00', '']
# ['mer,', '18.', 'oct', '2017', '07:21', '']
# ['mer,', '18.', 'oct', '2017', '07:48', '']
# ['mer,', '18.', 'oct', '2017', '08:02', '']
# ['mer,', '18.', 'oct', '2017', '08:17', '']
# ['mer,', '18.', 'oct', '2017', '08:30', '']
# ['mer,', '18.', 'oct', '2017', '09:00', '']
# ['mer,', '18.', 'oct', '2017', '09:20', '']
# ['mer,', '18.', 'oct', '2017', '10:35', '']
# ['mer,', '18.', 'oct', '2017', '11:00', '']
# ['mer,', '18.', 'oct', '2017', '11:09', '']
# ['mer,', '18.', 'oct', '2017', '11:20', '']
# ['mer,', '18.', 'oct', '2017', '12:07', '']
# ['mer,', '18.', 'oct', '2017', '12:15', '']
# ['mer,', '18.', 'oct', '2017', '12:56', '']
# ['mer,', '18.', 'oct', '2017', '13:15', '']
# ['mer,', '18.', 'oct', '2017', '13:30', '']
# ['mer,', '18.', 'oct', '2017', '13:42', '']
# ['mer,', '18.', 'oct', '2017', '14:30', '']
# ['mer,', '18.', 'oct', '2017', '14:35', '']
# ['mer,', '18.', 'oct', '2017', '15:52', '']
# ['mer,', '18.', 'oct', '2017', '15:55', '']
# ['mer,', '18.', 'oct', '2017', '16:45', '']
# ['mer,', '18.', 'oct', '2017', '17:17', '']
# ['mer,', '18.', 'oct', '2017', '17:50', '']
# ['mer,', '18.', 'oct', '2017', '18:00', '']
# ['mer,', '18.', 'oct', '2017', '18:20', '']
# ['mer,', '18.', 'oct', '2017', '00:35', '']
# ['jeu,', '19.', 'oct', '2017', '07:48', '']
# ['jeu,', '19.', 'oct', '2017', '08:00', '']
# ['mer,', '18.', 'oct', '2017', '00:35', '']
# ['jeu,', '19.', 'oct', '2017', '07:48', '']
# ['jeu,', '19.', 'oct', '2017', '08:00', '']
# ['jeu,', '19.', 'oct', '2017', '08:02', '']
# ['jeu,', '19.', 'oct', '2017', '08:17', '']
# ['jeu,', '19.', 'oct', '2017', '08:30', '']
# ['jeu,', '19.', 'oct', '2017', '09:00', '']
# ['jeu,', '19.', 'oct', '2017', '09:11', '']
# ['jeu,', '19.', 'oct', '2017', '09:20', '']
# ['jeu,', '19.', 'oct', '2017', '09:58', '']
# ['jeu,', '19.', 'oct', '2017', '10:35', '']
# ['jeu,', '19.', 'oct', '2017', '11:00', '']
# ['jeu,', '19.', 'oct', '2017', '11:00', '']
# ['jeu,', '19.', 'oct', '2017', '11:09', '']
# ['jeu,', '19.', 'oct', '2017', '11:20', '']
# ['jeu,', '19.', 'oct', '2017', '12:07', '']
# ['jeu,', '19.', 'oct', '2017', '12:56', '']
# ['jeu,', '19.', 'oct', '2017', '13:30', '']
# ['jeu,', '19.', 'oct', '2017', '14:00', '']
# ['jeu,', '19.', 'oct', '2017', '14:35', '']
# ['jeu,', '19.', 'oct', '2017', '15:10', '']
# ['jeu,', '19.', 'oct', '2017', '15:52', '']
# ['jeu,', '19.', 'oct', '2017', '16:35', '']
# ['jeu,', '19.', 'oct', '2017', '16:45', '']
# ['jeu,', '19.', 'oct', '2017', '17:17', '']
# ['jeu,', '19.', 'oct', '2017', '17:39', '']
# ['jeu,', '19.', 'oct', '2017', '18:00', '']
# ['jeu,', '19.', 'oct', '2017', '18:00', '']
# ['jeu,', '19.', 'oct', '2017', '18:20', '']
# ['ven,', '20.', 'oct', '2017', '07:48', '']
# ['ven,', '20.', 'oct', '2017', '07:48', '']
# ['ven,', '20.', 'oct', '2017', '08:00', '']
# ['ven,', '20.', 'oct', '2017', '08:17', '']
# ['ven,', '20.', 'oct', '2017', '08:30', '']
# ['ven,', '20.', 'oct', '2017', '08:44', '']
# ['ven,', '20.', 'oct', '2017', '09:00', '']
# ['ven,', '20.', 'oct', '2017', '09:11', '']
# ['ven,', '20.', 'oct', '2017', '09:20', '']
# ['ven,', '20.', 'oct', '2017', '10:35', '']
# ['ven,', '20.', 'oct', '2017', '11:00', '']
# ['ven,', '20.', 'oct', '2017', '11:00', '']
# ['ven,', '20.', 'oct', '2017', '11:09', '']
# ['ven,', '20.', 'oct', '2017', '11:20', '']
# ['ven,', '20.', 'oct', '2017', '12:00', '']
# ['ven,', '20.', 'oct', '2017', '12:12', '']
# ['ven,', '20.', 'oct', '2017', '12:29', '']
# ['ven,', '20.', 'oct', '2017', '12:50', '']
# ['ven,', '20.', 'oct', '2017', '13:30', '']
# ['ven,', '20.', 'oct', '2017', '13:30', '']
# ['ven,', '20.', 'oct', '2017', '13:30', '']
# ['ven,', '20.', 'oct', '2017', '14:35', '']
# ['ven,', '20.', 'oct', '2017', '14:50', '']
# ['ven,', '20.', 'oct', '2017', '15:52', '']
# ['ven,', '20.', 'oct', '2017', '16:35', '']
# ['ven,', '20.', 'oct', '2017', '16:45', '']
# ['ven,', '20.', 'oct', '2017', '17:17', '']
# ['ven,', '20.', 'oct', '2017', '17:39', '']
# ['sam,', '21.', 'oct', '2017', '07:00', '']
# ['sam,', '21.', 'oct', '2017', '07:48', '']
# ['sam,', '21.', 'oct', '2017', '08:02', '']
# ['sam,', '21.', 'oct', '2017', '08:15', '']
# ['sam,', '21.', 'oct', '2017', '08:17', '']
# ['sam,', '21.', 'oct', '2017', '08:30', '']
# ['sam,', '21.', 'oct', '2017', '09:00', '']
# ['sam,', '21.', 'oct', '2017', '09:11', '']
# ['sam,', '21.', 'oct', '2017', '09:20', '']
# ['sam,', '21.', 'oct', '2017', '10:35', '']
# ['sam,', '21.', 'oct', '2017', '11:00', '']
# ['sam,', '21.', 'oct', '2017', '11:09', '']
# ['sam,', '21.', 'oct', '2017', '11:20', '']
# ['sam,', '21.', 'oct', '2017', '12:07', '']
# ['sam,', '21.', 'oct', '2017', '12:15', '']
# ['sam,', '21.', 'oct', '2017', '12:56', '']
# ['sam,', '21.', 'oct', '2017', '13:00', '']
# ['sam,', '21.', 'oct', '2017', '13:05', '']
# ['sam,', '21.', 'oct', '2017', '13:07', '']
# ['sam,', '21.', 'oct', '2017', '13:30', '']
# ['sam,', '21.', 'oct', '2017', '13:30', '']
# ['sam,', '21.', 'oct', '2017', '13:50', '']
# ['sam,', '21.', 'oct', '2017', '14:50', '']
# ['sam,', '21.', 'oct', '2017', '15:52', '']
# ['sam,', '21.', 'oct', '2017', '16:35', '']
# ['sam,', '21.', 'oct', '2017', '16:45', '']
# ['sam,', '21.', 'oct', '2017', '17:17', '']
# ['sam,', '21.', 'oct', '2017', '17:39', '']
# ['dim,', '22.', 'oct', '2017', '07:48', '']
# ['dim,', '22.', 'oct', '2017', '08:00', '']
# ['dim,', '22.', 'oct', '2017', '08:02', '']
# ['dim,', '22.', 'oct', '2017', '08:17', '']
# ['dim,', '22.', 'oct', '2017', '08:30', '']
# ['dim,', '22.', 'oct', '2017', '09:00', '']
# ['dim,', '22.', 'oct', '2017', '09:10', '']
# ['dim,', '22.', 'oct', '2017', '09:11', '']
# ['dim,', '22.', 'oct', '2017', '09:20', '']
# ['dim,', '22.', 'oct', '2017', '11:09', '']
# ['dim,', '22.', 'oct', '2017', '11:20', '']
# ['dim,', '22.', 'oct', '2017', '12:56', '']
# ['dim,', '22.', 'oct', '2017', '13:15', '']
# ['dim,', '22.', 'oct', '2017', '13:15', '']
# ['dim,', '22.', 'oct', '2017', '13:30', '']
# ['dim,', '22.', 'oct', '2017', '13:30', '']
# ['dim,', '22.', 'oct', '2017', '13:30', '']
# ['dim,', '22.', 'oct', '2017', '14:00', '']
# ['dim,', '22.', 'oct', '2017', '14:35', '']
# ['dim,', '22.', 'oct', '2017', '16:35', '']
# ['dim,', '22.', 'oct', '2017', '16:45', '']
# ['dim,', '22.', 'oct', '2017', '17:17', '']
# ['dim,', '22.', 'oct', '2017', '17:39', '']
# ['dim,', '22.', 'oct', '2017', '18:00', '']
# ['dim,', '22.', 'oct', '2017', '18:00', '']
# ['dim,', '22.', 'oct', '2017', '18:20', '']
# ['dim,', '22.', 'oct', '2017', '19:45', '']
# ['dim,', '22.', 'oct', '2017', '19:45', '']
# ['lun,', '23.', 'oct', '2017', '07:48', '']
# ['lun,', '23.', 'oct', '2017', '08:00', '']
# ['lun,', '23.', 'oct', '2017', '08:02', '']
# ['lun,', '23.', 'oct', '2017', '08:17', '']
# ['lun,', '23.', 'oct', '2017', '08:30', '']
# ['lun,', '23.', 'oct', '2017', '09:00', '']
# ['lun,', '23.', 'oct', '2017', '09:11', '']
# ['lun,', '23.', 'oct', '2017', '09:20', '']
# ['lun,', '23.', 'oct', '2017', '10:00', '']
# ['lun,', '23.', 'oct', '2017', '10:09', '']
# ['lun,', '23.', 'oct', '2017', '10:35', '']
# ['lun,', '23.', 'oct', '2017', '11:00', '']
# ['lun,', '23.', 'oct', '2017', '11:00', '']
# ['lun,', '23.', 'oct', '2017', '11:09', '']
# ['lun,', '23.', 'oct', '2017', '11:20', '']
# ['lun,', '23.', 'oct', '2017', '11:22', '']
# ['lun,', '23.', 'oct', '2017', '11:50', '']
# ['lun,', '23.', 'oct', '2017', '12:50', '']
# ['lun,', '23.', 'oct', '2017', '12:56', '']
# ['lun,', '23.', 'oct', '2017', '13:30', '']
# ['lun,', '23.', 'oct', '2017', '15:52', '']
# ['lun,', '23.', 'oct', '2017', '16:35', '']
# ['lun,', '23.', 'oct', '2017', '16:45', '']
# ['lun,', '23.', 'oct', '2017', '17:17', '']
# ['lun,', '23.', 'oct', '2017', '17:39', '']
# ['lun,', '23.', 'oct', '2017', '17:50', '']
# ['lun,', '23.', 'oct', '2017', '18:00', '']
# ['lun,', '23.', 'oct', '2017', '18:20', '']
# ['mar,', '24.', 'oct', '2017', '07:48', '']
# ['mar,', '24.', 'oct', '2017', '07:48', '']
# ['mar,', '24.', 'oct', '2017', '08:02', '']
# ['mar,', '24.', 'oct', '2017', '08:17', '']
# ['mar,', '24.', 'oct', '2017', '08:30', '']
# ['mar,', '24.', 'oct', '2017', '09:00', '']
# ['mar,', '24.', 'oct', '2017', '09:20', '']
# ['mar,', '24.', 'oct', '2017', '10:35', '']
# ['mar,', '24.', 'oct', '2017', '11:00', '']
# ['mar,', '24.', 'oct', '2017', '11:00', '']
# ['mar,', '24.', 'oct', '2017', '11:01', '']
# ['mar,', '24.', 'oct', '2017', '11:20', '']
# ['mar,', '24.', 'oct', '2017', '12:00', '']
# ['mar,', '24.', 'oct', '2017', '12:07', '']
# ['mar,', '24.', 'oct', '2017', '12:45', '']
# ['mar,', '24.', 'oct', '2017', '12:56', '']
# ['mar,', '24.', 'oct', '2017', '13:15', '']
# ['mar,', '24.', 'oct', '2017', '13:30', '']
# ['mar,', '24.', 'oct', '2017', '13:45', '']
# ['mar,', '24.', 'oct', '2017', '13:50', '']
# ['mar,', '24.', 'oct', '2017', '14:12', '']
# ['mar,', '24.', 'oct', '2017', '14:25', '']
# ['mar,', '24.', 'oct', '2017', '15:15', '']
# ['mar,', '24.', 'oct', '2017', '15:52', '']
# ['mar,', '24.', 'oct', '2017', '16:35', '']
# ['mar,', '24.', 'oct', '2017', '16:45', '']
# ['mar,', '24.', 'oct', '2017', '17:17', '']
# ['mar,', '24.', 'oct', '2017', '18:00', '']
# ['mar,', '24.', 'oct', '2017', '18:00', '']
# ['mar,', '24.', 'oct', '2017', '19:00', '']
# ['mer,', '25.', 'oct', '2017', '07:00', '']
# ['mer,', '25.', 'oct', '2017', '07:00', '']
# ['mer,', '25.', 'oct', '2017', '07:48', '']
# ['mer,', '25.', 'oct', '2017', '08:02', '']
# ['mer,', '25.', 'oct', '2017', '08:17', '']
# ['mer,', '25.', 'oct', '2017', '08:30', '']
# ['mer,', '25.', 'oct', '2017', '09:00', '']
# ['mer,', '25.', 'oct', '2017', '09:20', '']
# ['mer,', '25.', 'oct', '2017', '10:35', '']
# ['mer,', '25.', 'oct', '2017', '11:00', '']
# ['mer,', '25.', 'oct', '2017', '11:09', '']
# ['mer,', '25.', 'oct', '2017', '11:20', '']
# ['mer,', '25.', 'oct', '2017', '12:07', '']
# ['mer,', '25.', 'oct', '2017', '12:56', '']
# ['mer,', '25.', 'oct', '2017', '13:15', '']
# ['mer,', '25.', 'oct', '2017', '13:30', '']
# ['mer,', '25.', 'oct', '2017', '14:08', '']
# ['mer,', '25.', 'oct', '2017', '14:30', '']
# ['mer,', '25.', 'oct', '2017', '14:35', '']
# ['mer,', '25.', 'oct', '2017', '15:52', '']
# ['mer,', '25.', 'oct', '2017', '15:55', '']
# ['mer,', '25.', 'oct', '2017', '16:45', '']
# ['mer,', '25.', 'oct', '2017', '17:17', '']
# ['mer,', '25.', 'oct', '2017', '17:50', '']
# ['mer,', '25.', 'oct', '2017', '18:00', '']
# ['mer,', '25.', 'oct', '2017', '18:20', '']
# ['jeu,', '26.', 'oct', '2017', '07:48', '']
# ['jeu,', '26.', 'oct', '2017', '08:00', '']
# ['jeu,', '26.', 'oct', '2017', '08:02', '']
# ['jeu,', '26.', 'oct', '2017', '08:17', '']
# ['jeu,', '26.', 'oct', '2017', '08:30', '']
# ['jeu,', '26.', 'oct', '2017', '07:48', '']
# ['jeu,', '26.', 'oct', '2017', '08:00', '']
# ['jeu,', '26.', 'oct', '2017', '08:02', '']
# ['jeu,', '26.', 'oct', '2017', '08:17', '']
# ['jeu,', '26.', 'oct', '2017', '08:30', '']
# ['jeu,', '26.', 'oct', '2017', '08:58', '']
# ['jeu,', '26.', 'oct', '2017', '09:00', '']
# ['jeu,', '26.', 'oct', '2017', '09:09', '']
# ['jeu,', '26.', 'oct', '2017', '09:20', '']
# ['jeu,', '26.', 'oct', '2017', '10:35', '']
# ['jeu,', '26.', 'oct', '2017', '11:00', '']
# ['jeu,', '26.', 'oct', '2017', '11:00', '']
# ['jeu,', '26.', 'oct', '2017', '11:09', '']
# ['jeu,', '26.', 'oct', '2017', '11:20', '']
# ['jeu,', '26.', 'oct', '2017', '12:07', '']
# ['jeu,', '26.', 'oct', '2017', '12:56', '']
# ['jeu,', '26.', 'oct', '2017', '13:30', '']
# ['jeu,', '26.', 'oct', '2017', '14:00', '']
# ['jeu,', '26.', 'oct', '2017', '14:21', '']
# ['jeu,', '26.', 'oct', '2017', '14:35', '']
# ['jeu,', '26.', 'oct', '2017', '15:10', '']
# ['jeu,', '26.', 'oct', '2017', '15:41', '']
# ['jeu,', '26.', 'oct', '2017', '15:52', '']
# ['jeu,', '26.', 'oct', '2017', '16:35', '']
# ['jeu,', '26.', 'oct', '2017', '16:45', '']
# ['jeu,', '26.', 'oct', '2017', '17:17', '']
# ['jeu,', '26.', 'oct', '2017', '17:39', '']
# ['jeu,', '26.', 'oct', '2017', '18:00', '']
# ['jeu,', '26.', 'oct', '2017', '18:00', '']
# ['jeu,', '26.', 'oct', '2017', '18:20', '']
# ['ven,', '27.', 'oct', '2017', '07:43', '']
# ['ven,', '27.', 'oct', '2017', '07:48', '']
# ['ven,', '27.', 'oct', '2017', '08:00', '']
# ['ven,', '27.', 'oct', '2017', '08:17', '']
# ['ven,', '27.', 'oct', '2017', '08:30', '']
# ['ven,', '27.', 'oct', '2017', '08:36', '']
# ['ven,', '27.', 'oct', '2017', '09:00', '']
# ['ven,', '27.', 'oct', '2017', '09:11', '']
# ['ven,', '27.', 'oct', '2017', '09:20', '']
# ['ven,', '27.', 'oct', '2017', '10:15', '']
# ['ven,', '27.', 'oct', '2017', '10:35', '']
# ['ven,', '27.', 'oct', '2017', '11:00', '']
# ['ven,', '27.', 'oct', '2017', '11:00', '']
# ['ven,', '27.', 'oct', '2017', '11:09', '']
# ['ven,', '27.', 'oct', '2017', '11:20', '']
# ['ven,', '27.', 'oct', '2017', '11:50', '']
# ['ven,', '27.', 'oct', '2017', '12:50', '']
# ['ven,', '27.', 'oct', '2017', '12:56', '']
# ['ven,', '27.', 'oct', '2017', '12:57', '']
# ['ven,', '27.', 'oct', '2017', '', '13:10', '']
# ['ven,', '27.', 'oct', '2017', '13:30', '']
# ['ven,', '27.', 'oct', '2017', '14:35', '']
# ['ven,', '27.', 'oct', '2017', '15:52', '']
# ['ven,', '27.', 'oct', '2017', '16:35', '']
# ['ven,', '27.', 'oct', '2017', '16:45', '']
# ['ven,', '27.', 'oct', '2017', '17:17', '']
# ['ven,', '27.', 'oct', '2017', '17:39', '']
# ['ven,', '27.', 'oct', '2017', '18:00', '']
# ['ven,', '27.', 'oct', '2017', '18:20', '']
# ['ven,', '27.', 'oct', '2017', '19:00', '']
# ['sam,', '28.', 'oct', '2017', '07:00', '']
# ['sam,', '28.', 'oct', '2017', '07:17', '']
# ['sam,', '28.', 'oct', '2017', '07:46', '']
# ['sam,', '28.', 'oct', '2017', '07:48', '']
# ['sam,', '28.', 'oct', '2017', '08:02', '']
# ['sam,', '28.', 'oct', '2017', '08:17', '']
# ['sam,', '28.', 'oct', '2017', '08:30', '']
# ['sam,', '28.', 'oct', '2017', '08:31', '']
# ['sam,', '28.', 'oct', '2017', '09:00', '']
# ['sam,', '28.', 'oct', '2017', '09:11', '']
# ['sam,', '28.', 'oct', '2017', '09:20', '']
# ['sam,', '28.', 'oct', '2017', '10:35', '']
# ['sam,', '28.', 'oct', '2017', '11:00', '']
# ['sam,', '28.', 'oct', '2017', '11:05', '']
# ['sam,', '28.', 'oct', '2017', '11:09', '']
# ['sam,', '28.', 'oct', '2017', '11:20', '']
# ['sam,', '28.', 'oct', '2017', '12:00', '']
# ['sam,', '28.', 'oct', '2017', '12:07', '']
# ['sam,', '28.', 'oct', '2017', '12:56', '']
# ['sam,', '28.', 'oct', '2017', '13:30', '']
# ['sam,', '28.', 'oct', '2017', '13:30', '']
# ['sam,', '28.', 'oct', '2017', '13:50', '']
# ['sam,', '28.', 'oct', '2017', '14:15', '']
# ['sam,', '28.', 'oct', '2017', '14:35', '']
# ['sam,', '28.', 'oct', '2017', '15:52', '']
# ['sam,', '28.', 'oct', '2017', '16:35', '']
# ['sam,', '28.', 'oct', '2017', '16:45', '']
# ['sam,', '28.', 'oct', '2017', '17:17', '']
# ['dim,', '29.', 'oct', '2017', '08:00', '']
# ['dim,', '29.', 'oct', '2017', '08:02', '']
# ['dim,', '29.', 'oct', '2017', '08:17', '']
# ['dim,', '29.', 'oct', '2017', '08:18', '']
# ['dim,', '29.', 'oct', '2017', '08:30', '']
# ['dim,', '29.', 'oct', '2017', '08:56', '']
# ['dim,', '29.', 'oct', '2017', '09:00', '']
# ['dim,', '29.', 'oct', '2017', '09:11', '']
# ['dim,', '29.', 'oct', '2017', '09:20', '']
# ['dim,', '29.', 'oct', '2017', '10:14', '']
# ['dim,', '29.', 'oct', '2017', '11:20', '']
# ['dim,', '29.', 'oct', '2017', '12:56', '']
# ['dim,', '29.', 'oct', '2017', '13:15', '']
# ['dim,', '29.', 'oct', '2017', '13:30', '']
# ['dim,', '29.', 'oct', '2017', '13:30', '']
# ['dim,', '29.', 'oct', '2017', '13:30', '']
# ['dim,', '29.', 'oct', '2017', '13:51', '']
# ['dim,', '29.', 'oct', '2017', '14:00', '']
# ['dim,', '29.', 'oct', '2017', '14:35', '']
# ['dim,', '29.', 'oct', '2017', '14:55', '']
# ['dim,', '29.', 'oct', '2017', '15:32', '']
# ['dim,', '29.', 'oct', '2017', '16:35', '']
# ['dim,', '29.', 'oct', '2017', '16:45', '']
# ['dim,', '29.', 'oct', '2017', '17:17', '']
# ['dim,', '29.', 'oct', '2017', '17:39', '']
# ['dim,', '29.', 'oct', '2017', '18:00', '']
# ['dim,', '29.', 'oct', '2017', '18:00', '']
# ['dim,', '29.', 'oct', '2017', '18:35', '']
# ['dim,', '29.', 'oct', '2017', '19:45', '']
# ['lun,', '30.', 'oct', '2017', '08:00', '']
# ['lun,', '30.', 'oct', '2017', '08:02', '']
# ['lun,', '30.', 'oct', '2017', '08:17', '']
# ['lun,', '30.', 'oct', '2017', '08:18', '']
# ['lun,', '30.', 'oct', '2017', '08:30', '']
# ['lun,', '30.', 'oct', '2017', '09:00', '']
# ['lun,', '30.', 'oct', '2017', '09:11', '']
# ['lun,', '30.', 'oct', '2017', '09:20', '']
# ['lun,', '30.', 'oct', '2017', '10:35', '']
# ['lun,', '30.', 'oct', '2017', '11:00', '']
# ['lun,', '30.', 'oct', '2017', '11:00', '']
# ['lun,', '30.', 'oct', '2017', '11:15', '']
# ['lun,', '30.', 'oct', '2017', '11:20', '']
# ['lun,', '30.', 'oct', '2017', '11:50', '']
# ['lun,', '30.', 'oct', '2017', '12:29', '']
# ['lun,', '30.', 'oct', '2017', '12:50', '']
# ['lun,', '30.', 'oct', '2017', '12:56', '']
# ['lun,', '30.', 'oct', '2017', '13:30', '']
# ['lun,', '30.', 'oct', '2017', '13:51', '']
# ['lun,', '30.', 'oct', '2017', '14:35', '']
# ['lun,', '30.', 'oct', '2017', '15:32', '']
# ['lun,', '30.', 'oct', '2017', '16:35', '']
# ['lun,', '30.', 'oct', '2017', '16:45', '']
# ['lun,', '30.', 'oct', '2017', '17:17', '']
# ['lun,', '30.', 'oct', '2017', '17:39', '']
# ['lun,', '30.', 'oct', '2017', '17:50', '']
# ['lun,', '30.', 'oct', '2017', '18:00', '']
# ['lun,', '30.', 'oct', '2017', '18:35', '']
# ['mar,', '31.', 'oct', '2017', '09:02', '']
# ['mar,', '31.', 'oct', '2017', '09:17', '']
# ['mar,', '31.', 'oct', '2017', '09:02', '']
# ['mar,', '31.', 'oct', '2017', '09:17', '']
# ['mar,', '31.', 'oct', '2017', '09:18', '']
# ['mar,', '31.', 'oct', '2017', '09:30', '']
# ['mar,', '31.', 'oct', '2017', '10:00', '']
# ['mar,', '31.', 'oct', '2017', '10:20', '']
# ['mar,', '31.', 'oct', '2017', '11:35', '']
# ['mar,', '31.', 'oct', '2017', '12:00', '']
# ['mar,', '31.', 'oct', '2017', '12:15', '']
# ['mar,', '31.', 'oct', '2017', '12:20', '']
# ['mar,', '31.', 'oct', '2017', '12:40', '']
# ['mar,', '31.', 'oct', '2017', '13:07', '']
# ['mar,', '31.', 'oct', '2017', '13:56', '']
# ['mar,', '31.', 'oct', '2017', '14:30', '']
# ['mar,', '31.', 'oct', '2017', '14:30', '']
# ['mar,', '31.', 'oct', '2017', '14:30', '']
# ['mar,', '31.', 'oct', '2017', '14:50', '']
# ['mar,', '31.', 'oct', '2017', '14:51', '']
# ['mar,', '31.', 'oct', '2017', '15:55', '']
# ['mar,', '31.', 'oct', '2017', '16:32', '']
# ['mar,', '31.', 'oct', '2017', '17:35', '']
# ['mar,', '31.', 'oct', '2017', '17:45', '']
# ['mar,', '31.', 'oct', '2017', '18:17', '']
# ['mar,', '31.', 'oct', '2017', '19:00', '']
# ['mar,', '31.', 'oct', '2017', '19:00', '']
# ['mar,', '31.', 'oct', '2017', '19:04', '']
# ['mar,', '31.', 'oct', '2017', '20:00', '']
# ['mer,', '01.', 'nov', '2017', '08:00', '']
# ['mer,', '01.', 'nov', '2017', '08:00', '']
# ['mer,', '01.', 'nov', '2017', '09:17', '']
# ['mer,', '01.', 'nov', '2017', '09:18', '']
# ['mer,', '01.', 'nov', '2017', '09:30', '']
# ['mer,', '01.', 'nov', '2017', '10:00', '']
# ['mer,', '01.', 'nov', '2017', '10:20', '']
# ['mer,', '01.', 'nov', '2017', '11:35', '']
# ['mer,', '01.', 'nov', '2017', '12:00', '']
# ['mer,', '01.', 'nov', '2017', '12:20', '']
# ['mer,', '01.', 'nov', '2017', '13:07', '']
# ['mer,', '01.', 'nov', '2017', '13:56', '']
# ['mer,', '01.', 'nov', '2017', '14:15', '']
# ['mer,', '01.', 'nov', '2017', '14:25', '']
# ['mer,', '01.', 'nov', '2017', '14:30', '']
# ['mer,', '01.', 'nov', '2017', '14:50', '']
# ['mer,', '01.', 'nov', '2017', '14:51', '']
# ['mer,', '01.', 'nov', '2017', '15:35', '']
# ['mer,', '01.', 'nov', '2017', '16:32', '']
# ['mer,', '01.', 'nov', '2017', '16:55', '']
# ['mer,', '01.', 'nov', '2017', '17:45', '']
# ['mer,', '01.', 'nov', '2017', '18:17', '']
# ['mer,', '01.', 'nov', '2017', '18:21', '']
# ['mer,', '01.', 'nov', '2017', '18:50', '']
# ['mer,', '01.', 'nov', '2017', '19:00', '']
# ['mer,', '01.', 'nov', '2017', '19:35', '']
# ['jeu,', '02.', 'nov', '2017', '09:00', '']
# ['jeu,', '02.', 'nov', '2017', '09:02', '']
# ['jeu,', '02.', 'nov', '2017', '09:17', '']
# ['jeu,', '02.', 'nov', '2017', '09:18', '']
# ['jeu,', '02.', 'nov', '2017', '09:00', '']
# ['jeu,', '02.', 'nov', '2017', '09:02', '']
# ['jeu,', '02.', 'nov', '2017', '09:17', '']
# ['jeu,', '02.', 'nov', '2017', '09:18', '']
# ['jeu,', '02.', 'nov', '2017', '09:30', '']
# ['jeu,', '02.', 'nov', '2017', '10:00', '']
# ['jeu,', '02.', 'nov', '2017', '10:11', '']
# ['jeu,', '02.', 'nov', '2017', '10:20', '']
# ['jeu,', '02.', 'nov', '2017', '10:22', '']
# ['jeu,', '02.', 'nov', '2017', '11:35', '']
# ['jeu,', '02.', 'nov', '2017', '12:00', '']
# ['jeu,', '02.', 'nov', '2017', '12:15', '']
# ['jeu,', '02.', 'nov', '2017', '12:20', '']
# ['jeu,', '02.', 'nov', '2017', '13:07', '']
# ['jeu,', '02.', 'nov', '2017', '13:52', '']
# ['jeu,', '02.', 'nov', '2017', '13:56', '']
# ['jeu,', '02.', 'nov', '2017', '14:30', '']
# ['jeu,', '02.', 'nov', '2017', '14:51', '']
# ['jeu,', '02.', 'nov', '2017', '15:00', '']
# ['jeu,', '02.', 'nov', '2017', '15:35', '']
# ['jeu,', '02.', 'nov', '2017', '16:20', '']
# ['jeu,', '02.', 'nov', '2017', '16:32', '']
# ['jeu,', '02.', 'nov', '2017', '17:35', '']
# ['jeu,', '02.', 'nov', '2017', '17:45', '']
# ['jeu,', '02.', 'nov', '2017', '18:17', '']
# ['jeu,', '02.', 'nov', '2017', '18:39', '']
# ['jeu,', '02.', 'nov', '2017', '19:00', '']
# ['jeu,', '02.', 'nov', '2017', '19:00', '']
# ['jeu,', '02.', 'nov', '2017', '19:35', '']
# ['ven,', '03.', 'nov', '2017', '09:00', '']
# ['ven,', '03.', 'nov', '2017', '09:00', '']
# ['ven,', '03.', 'nov', '2017', '09:02', '']
# ['ven,', '03.', 'nov', '2017', '09:17', '']
# ['ven,', '03.', 'nov', '2017', '09:18', '']
# ['ven,', '03.', 'nov', '2017', '09:30', '']
# ['ven,', '03.', 'nov', '2017', '10:00', '']
# ['ven,', '03.', 'nov', '2017', '10:11', '']
# ['ven,', '03.', 'nov', '2017', '10:20', '']
# ['ven,', '03.', 'nov', '2017', '11:06', '']
# ['ven,', '03.', 'nov', '2017', '11:35', '']
# ['ven,', '03.', 'nov', '2017', '12:00', '']
# ['ven,', '03.', 'nov', '2017', '12:15', '']
# ['ven,', '03.', 'nov', '2017', '12:20', '']
# ['ven,', '03.', 'nov', '2017', '12:50', '']
# ['ven,', '03.', 'nov', '2017', '13:00', '']
# ['ven,', '03.', 'nov', '2017', '13:50', '']
# ['ven,', '03.', 'nov', '2017', '13:56', '']
# ['ven,', '03.', 'nov', '2017', '14:10', '']
# ['ven,', '03.', 'nov', '2017', '14:30', '']
# ['ven,', '03.', 'nov', '2017', '14:41', '']
# ['ven,', '03.', 'nov', '2017', '14:51', '']
# ['ven,', '03.', 'nov', '2017', '14:59', '']
# ['ven,', '03.', 'nov', '2017', '15:35', '']
# ['ven,', '03.', 'nov', '2017', '16:32', '']
# ['ven,', '03.', 'nov', '2017', '17:35', '']
# ['ven,', '03.', 'nov', '2017', '17:45', '']
# ['ven,', '03.', 'nov', '2017', '18:17', '']
# ['ven,', '03.', 'nov', '2017', '18:39', '']
# ['ven,', '03.', 'nov', '2017', '19:00', '']
# ['ven,', '03.', 'nov', '2017', '19:35', '']
# ['sam,', '04.', 'nov', '2017', '08:00', '']
# ['sam,', '04.', 'nov', '2017', '09:02', '']
# ['sam,', '04.', 'nov', '2017', '09:17', '']
# ['sam,', '04.', 'nov', '2017', '09:18', '']
# ['sam,', '04.', 'nov', '2017', '09:30', '']
# ['sam,', '04.', 'nov', '2017', '10:00', '']
# ['sam,', '04.', 'nov', '2017', '10:11', '']
# ['sam,', '04.', 'nov', '2017', '10:20', '']
# ['sam,', '04.', 'nov', '2017', '11:35', '']
# ['sam,', '04.', 'nov', '2017', '12:15', '']
# ['sam,', '04.', 'nov', '2017', '12:20', '']
# ['sam,', '04.', 'nov', '2017', '12:55', '']
# ['sam,', '04.', 'nov', '2017', '13:07', '']
# ['sam,', '04.', 'nov', '2017', '13:15', '']
# ['sam,', '04.', 'nov', '2017', '13:56', '']
# ['sam,', '04.', 'nov', '2017', '14:03', '']
# ['sam,', '04.', 'nov', '2017', '14:25', '']
# ['sam,', '04.', 'nov', '2017', '14:30', '']
# ['sam,', '04.', 'nov', '2017', '14:30', '']
# ['sam,', '04.', 'nov', '2017', '14:50', '']
# ['sam,', '04.', 'nov', '2017', '14:51', '']
# ['sam,', '04.', 'nov', '2017', '15:30', '']
# ['sam,', '04.', 'nov', '2017', '15:35', '']
# ['sam,', '04.', 'nov', '2017', '16:32', '']
# ['sam,', '04.', 'nov', '2017', '17:35', '']
# ['sam,', '04.', 'nov', '2017', '17:45', '']
# ['sam,', '04.', 'nov', '2017', '18:17', '']
# ['sam,', '04.', 'nov', '2017', '18:39', '']
# ['sam,', '04.', 'nov', '2017', '18:45', '']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ...
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['dim,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['lun,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mar,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['mer,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['jeu,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['ven,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['sam,']
# ['dim,', '08.', 'mars', '08:44', '']
# ['dim,', '08.', 'mars', '09:03', '']
# ['dim,', '08.', 'mars', '09:30', '']
# ['dim,', '08.', 'mars', '09:48', '']
# ['dim,', '08.', 'mars', '11:08', '']
# ['dim,', '08.', 'mars', '12:41', '']
# ['dim,', '08.', 'mars', '12:43', '']
# ['dim,', '08.', 'mars', '13:00', '']
# ['dim,', '08.', 'mars', '14:00', '']
# ['dim,', '08.', 'mars', '15:50', '']
# ['dim,', '08.', 'mars', '16:45', '']
# ['dim,', '08.', 'mars', '17:51', '']
# ['dim,', '08.', 'mars', '18:35', '']
# ['dim,', '08.', 'mars', '08:44', '']
# ['dim,', '08.', 'mars', '09:03', '']
# ['dim,', '08.', 'mars', '09:30', '']
# ['dim,', '08.', 'mars', '09:48', '']
# ['dim,', '08.', 'mars', '11:08', '']
# ['dim,', '08.', 'mars', '12:41', '']
# ['dim,', '08.', 'mars', '12:43', '']
# ['dim,', '08.', 'mars', '13:00', '']
# ['dim,', '08.', 'mars', '14:00', '']
# ['dim,', '08.', 'mars', '15:50', '']
# ['dim,', '08.', 'mars', '16:45', '']
# ['dim,', '08.', 'mars', '17:51', '']
# ['dim,', '08.', 'mars', '18:35', '']
# ['lun,', '09.', 'mars', '08:30', '']
# ['lun,', '09.', 'mars', '08:44', '']
# ['lun,', '09.', 'mars', '09:03', '']
# ['lun,', '09.', 'mars', '09:48', '']
# ['lun,', '09.', 'mars', '11:05', '']
# ['lun,', '09.', 'mars', '11:08', '']
# ['lun,', '09.', 'mars', '11:13', '']
# ['lun,', '09.', 'mars', '11:26', '']
# ['lun,', '09.', 'mars', '11:55', '']
# ['lun,', '09.', 'mars', '11:55', '']
# ['lun,', '09.', 'mars', '12:28', '']
# ['lun,', '09.', 'mars', '12:41', '']
# ['lun,', '09.', 'mars', '13:00', '']
# ['lun,', '09.', 'mars', '13:35', '']
# ['lun,', '09.', 'mars', '13:35', '']
# ['lun,', '09.', 'mars', '17:51', '']
# ['lun,', '09.', 'mars', '08:30', '']
# ['lun,', '09.', 'mars', '08:44', '']
# ['lun,', '09.', 'mars', '09:03', '']
# ['lun,', '09.', 'mars', '09:48', '']
# ['lun,', '09.', 'mars', '11:05', '']
# ['lun,', '09.', 'mars', '11:08', '']
# ['lun,', '09.', 'mars', '11:13', '']
# ['lun,', '09.', 'mars', '11:26', '']
# ['lun,', '09.', 'mars', '11:55', '']
# ['lun,', '09.', 'mars', '11:55', '']
# ['lun,', '09.', 'mars', '12:28', '']
# ['lun,', '09.', 'mars', '12:41', '']
# ['lun,', '09.', 'mars', '13:00', '']
# ['lun,', '09.', 'mars', '13:35', '']
# ['lun,', '09.', 'mars', '13:35', '']
# ['lun,', '09.', 'mars', '17:51', '']
# ['mar,', '10.', 'mars', '08:30', '']
# ['mar,', '10.', 'mars', '08:44', '']
# ['mar,', '10.', 'mars', '09:03', '']
# ['mar,', '10.', 'mars', '09:25', '']
# ['mar,', '10.', 'mars', '09:48', '']
# ['mar,', '10.', 'mars', '11:08', '']
# ['mar,', '10.', 'mars', '11:55', '']
# ['mar,', '10.', 'mars', '12:41', '']
# ['mar,', '10.', 'mars', '12:43', '']
# ['mar,', '10.', 'mars', '12:44', '']
# ['mar,', '10.', 'mars', '13:00', '']
# ['mar,', '10.', 'mars', '14:34', '']
# ['mar,', '10.', 'mars', '14:35', '']
# ['mar,', '10.', 'mars', '08:30', '']
# ['mar,', '10.', 'mars', '08:44', '']
# ['mar,', '10.', 'mars', '09:03', '']
# ['mar,', '10.', 'mars', '09:25', '']
# ['mar,', '10.', 'mars', '09:48', '']
# ['mar,', '10.', 'mars', '11:08', '']
# ['mar,', '10.', 'mars', '11:55', '']
# ['mar,', '10.', 'mars', '12:41', '']
# ['mar,', '10.', 'mars', '12:43', '']
# ['mar,', '10.', 'mars', '12:44', '']
# ['mar,', '10.', 'mars', '13:00', '']
# ['mar,', '10.', 'mars', '14:34', '']
# ['mar,', '10.', 'mars', '14:35', '']
# ['mar,', '10.', 'mars', '14:55', '']
# ['mar,', '10.', 'mars', '15:54', '']
# ['mar,', '10.', 'mars', '17:51', '']
# ['mer,', '11.', 'mars', '08:30', '']
# ['mer,', '11.', 'mars', '08:44', '']
# ['mer,', '11.', 'mars', '09:00', '']
# ['mer,', '11.', 'mars', '09:03', '']
# ['mer,', '11.', 'mars', '11:08', '']
# ['mer,', '11.', 'mars', '11:55', '']
# ['mer,', '11.', 'mars', '12:15', '']
# ['mer,', '11.', 'mars', '12:41', '']
# ['mer,', '11.', 'mars', '12:43', '']
# ['mer,', '11.', 'mars', '12:50', '']
# ['mer,', '11.', 'mars', '14:30', '']
# ['mer,', '11.', 'mars', '17:15', '']
# ['mer,', '11.', 'mars', '18:35', '']
# ['mer,', '11.', 'mars', '08:30', '']
# ['mer,', '11.', 'mars', '08:44', '']
# ['mer,', '11.', 'mars', '09:00', '']
# ['mer,', '11.', 'mars', '09:03', '']
# ['mer,', '11.', 'mars', '11:08', '']
# ['mer,', '11.', 'mars', '11:55', '']
# ['mer,', '11.', 'mars', '12:15', '']
# ['mer,', '11.', 'mars', '12:41', '']
# ['mer,', '11.', 'mars', '12:43', '']
# ['mer,', '11.', 'mars', '12:50', '']
# ['mer,', '11.', 'mars', '14:30', '']
# ['mer,', '11.', 'mars', '17:15', '']
# ['mer,', '11.', 'mars', '18:35', '']
# ['jeu,', '12.', 'mars', '08:30', '']
# ['jeu,', '12.', 'mars', '08:44', '']
# ['jeu,', '12.', 'mars', '09:15', '']
# ['jeu,', '12.', 'mars', '11:05', '']
# ['jeu,', '12.', 'mars', '11:08', '']
# ['jeu,', '12.', 'mars', '11:55', '']
# ['jeu,', '12.', 'mars', '12:41', '']
# ['jeu,', '12.', 'mars', '12:43', '']
# ['jeu,', '12.', 'mars', '12:52', '']
# ['jeu,', '12.', 'mars', '12:52', '']
# ['jeu,', '12.', 'mars', '13:30', '']
# ['jeu,', '12.', 'mars', '15:42', '']
# ['jeu,', '12.', 'mars', '15:50', '']
# ['jeu,', '12.', 'mars', '17:15', '']
# ['jeu,', '12.', 'mars', '17:51', '']
# ['jeu,', '12.', 'mars', '08:30', '']
# ['jeu,', '12.', 'mars', '08:44', '']
# ['jeu,', '12.', 'mars', '09:15', '']
# ['jeu,', '12.', 'mars', '11:05', '']
# ['jeu,', '12.', 'mars', '11:08', '']
# ['jeu,', '12.', 'mars', '11:55', '']
# ['jeu,', '12.', 'mars', '12:41', '']
# ['jeu,', '12.', 'mars', '12:43', '']
# ['jeu,', '12.', 'mars', '12:52', '']
# ['jeu,', '12.', 'mars', '12:52', '']
# ['jeu,', '12.', 'mars', '13:30', '']
# ['jeu,', '12.', 'mars', '15:42', '']
# ['jeu,', '12.', 'mars', '15:50', '']
# ['jeu,', '12.', 'mars', '17:15', '']
# ['jeu,', '12.', 'mars', '17:51', '']
# ['jeu,', '12.', 'mars', '18:35', '']
# ['ven,', '13.', 'mars', '08:30', '']
# ['ven,', '13.', 'mars', '08:44', '']
# ['ven,', '13.', 'mars', '09:15', '']
# ['ven,', '13.', 'mars', '11:05', '']
# ['ven,', '13.', 'mars', '11:08', '']
# ['ven,', '13.', 'mars', '12:41', '']
# ['ven,', '13.', 'mars', '12:43', '']
# ['ven,', '13.', 'mars', '12:47', '']
# ['ven,', '13.', 'mars', '13:00', '']
# ['ven,', '13.', 'mars', '14:00', '']
# ['ven,', '13.', 'mars', '15:00', '']
# ['ven,', '13.', 'mars', '15:35', '']
# ['ven,', '13.', 'mars', '16:45', '']
# ['ven,', '13.', 'mars', '08:30', '']
# ['ven,', '13.', 'mars', '08:44', '']
# ['ven,', '13.', 'mars', '09:15', '']
# ['ven,', '13.', 'mars', '11:05', '']
# ['ven,', '13.', 'mars', '11:08', '']
# ['ven,', '13.', 'mars', '12:41', '']
# ['ven,', '13.', 'mars', '12:43', '']
# ['ven,', '13.', 'mars', '12:47', '']
# ['ven,', '13.', 'mars', '13:00', '']
# ['ven,', '13.', 'mars', '14:00', '']
# ['ven,', '13.', 'mars', '15:00', '']
# ['ven,', '13.', 'mars', '15:35', '']
# ['ven,', '13.', 'mars', '16:45', '']
# ['ven,', '13.', 'mars', '18:35', '']
# ['sam,', '14.', 'mars', '08:00', '']
# ['sam,', '14.', 'mars', '08:44', '']
# ['sam,', '14.', 'mars', '08:45', '']
# ['sam,', '14.', 'mars', '09:15', '']
# ['sam,', '14.', 'mars', '11:05', '']
# ['sam,', '14.', 'mars', '11:08', '']
# ['sam,', '14.', 'mars', '11:30', '']
# ['sam,', '14.', 'mars', '11:55', '']
# ['sam,', '14.', 'mars', '12:15', '']
# ['sam,', '14.', 'mars', '12:41', '']
# ['sam,', '14.', 'mars', '12:43', '']
# ['sam,', '14.', 'mars', '14:30', '']
# ['sam,', '14.', 'mars', '15:50', '']
# ['sam,', '14.', 'mars', '16:00', '']
# ['sam,', '14.', 'mars', '08:00', '']
# ['sam,', '14.', 'mars', '08:44', '']
# ['sam,', '14.', 'mars', '08:45', '']
# ['sam,', '14.', 'mars', '09:15', '']
# ['sam,', '14.', 'mars', '11:05', '']
# ['sam,', '14.', 'mars', '11:08', '']
# ['sam,', '14.', 'mars', '11:30', '']
# ['sam,', '14.', 'mars', '11:55', '']
# ['sam,', '14.', 'mars', '12:15', '']
# ['sam,', '14.', 'mars', '12:41', '']
# ['sam,', '14.', 'mars', '12:43', '']
# ['sam,', '14.', 'mars', '14:30', '']
# ['sam,', '14.', 'mars', '15:50', '']
# ['sam,', '14.', 'mars', '16:00', '']
# ['dim,', '15.', 'mars', '08:44', '']
# ['dim,', '15.', 'mars', '09:15', '']
# ['dim,', '15.', 'mars', '11:08', '']
# ['dim,', '15.', 'mars', '12:28', '']
# ['dim,', '15.', 'mars', '12:41', '']
# ['dim,', '15.', 'mars', '13:00', '']
# ['dim,', '15.', 'mars', '14:00', '']
# ['dim,', '15.', 'mars', '15:50', '']
# ['dim,', '15.', 'mars', '16:45', '']
# ['dim,', '15.', 'mars', '18:35', '']
# ['dim,', '15.', 'mars', '08:44', '']
# ['dim,', '15.', 'mars', '09:15', '']
# ['dim,', '15.', 'mars', '11:08', '']
# ['dim,', '15.', 'mars', '12:28', '']
# ['dim,', '15.', 'mars', '12:41', '']
# ['dim,', '15.', 'mars', '13:00', '']
# ['dim,', '15.', 'mars', '14:00', '']
# ['dim,', '15.', 'mars', '15:50', '']
# ['dim,', '15.', 'mars', '16:45', '']
# ['dim,', '15.', 'mars', '18:35', '']
# ['lun,', '16.', 'mars', '08:44', '']
# ['lun,', '16.', 'mars', '09:15', '']
# ['lun,', '16.', 'mars', '11:05', '']
# ['lun,', '16.', 'mars', '11:08', '']
# ['lun,', '16.', 'mars', '11:18', '']
# ['lun,', '16.', 'mars', '12:28', '']
# ['lun,', '16.', 'mars', '12:41', '']
# ['lun,', '16.', 'mars', '13:15', '']
# ['lun,', '16.', 'mars', '16:45', '']
# ['lun,', '16.', 'mars', '08:44', '']
# ['lun,', '16.', 'mars', '09:15', '']
# ['lun,', '16.', 'mars', '11:05', '']
# ['lun,', '16.', 'mars', '11:08', '']
# ['lun,', '16.', 'mars', '11:18', '']
# ['lun,', '16.', 'mars', '12:28', '']
# ['lun,', '16.', 'mars', '12:41', '']
# ['lun,', '16.', 'mars', '13:15', '']
# ['lun,', '16.', 'mars', '16:45', '']
# ['mar,', '17.', 'mars', '08:30', '']
# ['mar,', '17.', 'mars', '08:44', '']
# ['mar,', '17.', 'mars', '09:15', '']
# ['mar,', '17.', 'mars', '12:41', '']
# ['mar,', '17.', 'mars', '12:45', '']
# ['mar,', '17.', 'mars', '08:30', '']
# ['mar,', '17.', 'mars', '08:44', '']
# ['mar,', '17.', 'mars', '09:15', '']
# ['mar,', '17.', 'mars', '12:41', '']
# ['mar,', '17.', 'mars', '12:45', '']
# ['mer,', '18.', 'mars', '08:44', '']
# ['mer,', '18.', 'mars', '09:00', '']
# ['mer,', '18.', 'mars', '09:15', '']
# ['mer,', '18.', 'mars', '12:41', '']
# ['mer,', '18.', 'mars', '12:47', '']
# ['mer,', '18.', 'mars', '14:30', '']
# ['mer,', '18.', 'mars', '08:44', '']
# ['mer,', '18.', 'mars', '09:00', '']
# ['mer,', '18.', 'mars', '09:15', '']
# ['mer,', '18.', 'mars', '12:41', '']
# ['mer,', '18.', 'mars', '12:47', '']
# ['mer,', '18.', 'mars', '14:30', '']
# ['jeu,', '19.', 'mars', '08:44', '']
# ['jeu,', '19.', 'mars', '09:15', '']
# ['jeu,', '19.', 'mars', '12:41', '']
# ['jeu,', '19.', 'mars', '12:49', '']
# ['jeu,', '19.', 'mars', '08:44', '']
# ['jeu,', '19.', 'mars', '09:15', '']
# ['jeu,', '19.', 'mars', '12:41', '']
# ['jeu,', '19.', 'mars', '12:49', '']
# ['ven,', '20.', 'mars', '13:00', '']
# ['ven,', '20.', 'mars', '13:20', '']
# ['ven,', '20.', 'mars', '13:00', '']
# ['ven,', '20.', 'mars', '13:20', '']
# ['lun,', '23.', 'mars', '09:15', '']
# ['lun,', '23.', 'mars', '12:21', '']
# ['lun,', '23.', 'mars', '09:15', '']
# ['lun,', '23.', 'mars', '12:21', '']
# ['mar,', '24.', 'mars', '08:39', '']
# ['mar,', '24.', 'mars', '12:36', '']
# ['mar,', '24.', 'mars', '14:12', '']
# ['mar,', '24.', 'mars', '08:39', '']
# ['mar,', '24.', 'mars', '12:36', '']
# ['mar,', '24.', 'mars', '14:12', '']
# ['mer,', '25.', 'mars', '10:57', '']
# ['mer,', '25.', 'mars', '10:57', '']
# ['jeu,', '26.', 'mars', '10:56', '']
# ['jeu,', '26.', 'mars', '12:48', '']
# ['jeu,', '26.', 'mars', '13:33', '']
# ['jeu,', '26.', 'mars', '10:56', '']
# ['jeu,', '26.', 'mars', '12:48', '']
# ['jeu,', '26.', 'mars', '13:33', '']
# ['ven,', '27.', 'mars', '11:00', '']
# ['ven,', '27.', 'mars', '13:00', '']
# ['ven,', '27.', 'mars', '13:50', '']
# ['ven,', '27.', 'mars', '11:00', '']
# ['ven,', '27.', 'mars', '13:00', '']
# ['ven,', '27.', 'mars', '13:50', '']
# ['lun,', '30.', 'mars', '13:50', '']
# ['lun,', '30.', 'mars', '13:50', '']
# ['ven,', '03.', 'avr', '12:44', '']
# ['ven,', '03.', 'avr', '12:44', '']
# ['lun,', '06.', 'avr', '11:09', '']
# ['lun,', '06.', 'avr', '11:09', '']
# ['sam,', '11.', 'avr', '11:23', '']
# ['sam,', '11.', 'avr', '11:23', '']
# ['jeu,', '16.', 'avr', '21:45', '']
# ['jeu,', '16.', 'avr', '21:45', '']
# ['sam,', '18.', 'avr', '09:00', '']
# ['sam,', '18.', 'avr', '09:00', '']

# %%
df_final_review = df_final[~(df_final.date_text == '')].copy()

# %%
df_final_review[df_final_review['date_text'] == '03/08/08:44']
# Out:
# Empty DataFrame
# Columns: [Vol, De, Durée, Date, statut, arrival_planed_time, departure_time, departure_status, arriving_time, arriving_status, date_text]
# Index: []

# %%
# Convertion of time into minute
def duration(x):
    value =x.split('h')
    hour=0
    minute =0
    #print(value)
    if len(value)==2:
        hour = int(value[0])
        value2 = value[-1].split('m')
        if len(value2) ==2 :
            #print(value2)
            minute = int(value2[0])
        else:
            minute =0
        
            
    elif len(value) == 1 :
        minute = int(value[-1].split('m')[0])
    
    return float(hour*60+minute)

# %%
# Test of the function duration
duration('4h00')
# Out:
# 240.0

# %%
# function to say whether he is late or not
def is_late(x):
    if x > 0:
        return 1
    else :
        return 0

# %%
# Separationn of period
df_final_review['arrival_real_date_planed']= pd.DatetimeIndex(df_final_review['date_text'] + ' '+ df_final_review['arrival_planed_time'] ).date
df_final_review['arrival_real_date_time_planed'] =pd.DatetimeIndex(df_final_review['date_text'] + ' '+ df_final_review['arrival_planed_time'] )
df_final_review['arrival_real_date_time'] =pd.DatetimeIndex(df_final_review['date_text'] + ' '+ df_final_review['arriving_time'] )
df_final_review['month'] = pd.DatetimeIndex(df_final_review['date_text']).month
df_final_review['year']  = pd.DatetimeIndex(df_final_review['date_text']).year
df_final_review['hour'] =pd.DatetimeIndex(df_final_review['date_text'] + ' '+ df_final_review['arrival_planed_time'] ).hour
df_final_review['weekday'] = pd.DatetimeIndex(df_final_review['date_text']).weekday
df_final_review['quarter'] = pd.DatetimeIndex(df_final_review['date_text']).quarter
df_final_review['delay_in_minutes'] =(df_final_review['arrival_real_date_time'] - df_final_review['arrival_real_date_time_planed'] )/np.timedelta64(1,'m')
df_final_review['duration_in_minutes'] = df_final_review['Durée'].apply(lambda x :duration(x) )
df_final_review['is_late'] = df_final_review['delay_in_minutes'].apply(lambda x : is_late(x))

# %%
df_final_review.tail(2)
# Out:
#                                              Vol  \
# 31996  B66123 JBU6123 JetBlue Airways (B6 / JBU)
# 32000  B66123 JBU6123 JetBlue Airways (B6 / JBU)
#
#                                  De   Durée                 Date      statut  \
# 31996  Fort Lauderdale (FLL / KFLL)  5h 57m  sam, 18. avr 09:00    A Atterri
# 32000  Fort Lauderdale (FLL / KFLL)  5h 57m  sam, 18. avr 09:00    A Atterri
#
#       arrival_planed_time departure_time departure_status arriving_time  \
# 31996              09:00          06:40          planifié        12:37
# 32000              09:00          06:40          planifié        12:37
#
#           arriving_status  ... arrival_real_date_time_planed  \
# 31996   3 h 37 min retard  ...           2020-04-18 09:00:00
# 32000   3 h 37 min retard  ...           2020-04-18 09:00:00
#
#       arrival_real_date_time month  year  hour  weekday  quarter  \
# 31996    2020-04-18 12:37:00     4  2020     9        5        2
# 32000    2020-04-18 12:37:00     4  2020     9        5        2
#
#        delay_in_minutes  duration_in_minutes  is_late
# 31996             217.0                357.0        1
# 32000             217.0                357.0        1
#
# [2 rows x 22 columns]

# %%
# features
cols=['Vol','De','arrival_real_date_planed','arrival_real_date_time_planed','arrival_real_date_time','year','month','hour','weekday','quarter','delay_in_minutes'
,'duration_in_minutes','is_late']

# %%
df_final_review_ = df_final_review[cols]

# %%
df_final_review_.to_csv('final_dataset.csv')

# %%
df_final_review_.tail()
# Out:
#                                                   Vol  \
# 31950       NK6450 NKS6450 Spirit Airlines (NK / NKS)
# 31983  M6847 AJT847 Amerijet International (M6 / AJT)
# 31986  M6847 AJT847 Amerijet International (M6 / AJT)
# 31996       B66123 JBU6123 JetBlue Airways (B6 / JBU)
# 32000       B66123 JBU6123 JetBlue Airways (B6 / JBU)
#
#                                  De arrival_real_date_planed  \
# 31950  Fort Lauderdale (FLL / KFLL)               2020-04-11
# 31983            Miami (MIA / KMIA)               2020-04-16
# 31986            Miami (MIA / KMIA)               2020-04-16
# 31996  Fort Lauderdale (FLL / KFLL)               2020-04-18
# 32000  Fort Lauderdale (FLL / KFLL)               2020-04-18
#
#       arrival_real_date_time_planed arrival_real_date_time  year  month  hour  \
# 31950           2020-04-11 11:23:00    2020-04-11 11:25:00  2020      4    11
# 31983           2020-04-16 21:45:00    2020-04-16 21:45:00  2020      4    21
# 31986           2020-04-16 21:45:00    2020-04-16 21:45:00  2020      4    21
# 31996           2020-04-18 09:00:00    2020-04-18 12:37:00  2020      4     9
# 32000           2020-04-18 09:00:00    2020-04-18 12:37:00  2020      4     9
#
#        weekday  quarter  delay_in_minutes  duration_in_minutes  is_late
# 31950        5        2               2.0                145.0        1
# 31983        3        2               0.0                150.0        0
# 31986        3        2               0.0                150.0        0
# 31996        5        2             217.0                357.0        1
# 32000        5        2             217.0                357.0        1

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# The methodology in this project consists of two parts:
# - [Exploratory Data Analysis](#EDA): Consites a visauliser les trafics aerien, par jour, par compagnie, par mois, par trimestre.
#
#
#
# - [Modelling](#modelling): Avec la Machine Learning predire les retard de vols

# %% [markdown]
# After cleansing the data, it's time to start analyzing the data. This part here, this is the EDA.

# %% [markdown]
# ### Exploratory Data Analysis <a name="EDA"></a>

# %%
# About the new dataframe
df_final_review_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15012 entries, 0 to 32000
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Vol                            15012 non-null  object
#  1   De                             15012 non-null  object
#  2   arrival_real_date_planed       15012 non-null  object
#  3   arrival_real_date_time_planed  15012 non-null  datetime64[ns]
#  4   arrival_real_date_time         15012 non-null  datetime64[ns]
#  5   year                           15012 non-null  int64
#  6   month                          15012 non-null  int64
#  7   hour                           15012 non-null  int64
#  8   weekday                        15012 non-null  int64
#  9   quarter                        15012 non-null  int64
#  10  delay_in_minutes               15012 non-null  float64
#  11  duration_in_minutes            15012 non-null  float64
#  12  is_late                        15012 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(6), object(3)
# memory usage: 1.4+ MB

# %%
#flight group by date and delays
vol_per_date_late = df_final_review_[df_final_review_.is_late==1].groupby(['arrival_real_date_planed'])['is_late'].count().to_frame()

# %%
# per late
vol_per_date_late
# Out:
#                           is_late
# arrival_real_date_planed
# 2017-10-01                      6
# 2017-10-02                     10
# 2017-10-03                      3
# 2017-10-04                      6
# 2017-10-05                      2
# ...                           ...
# 2020-03-17                      2
# 2020-03-18                      2
# 2020-03-24                      2
# 2020-04-11                      2
# 2020-04-18                      2
#
# [518 rows x 1 columns]

# %%
vol_per_date = df_final_review_.groupby(['arrival_real_date_planed'])['is_late'].count().to_frame().rename(columns={'is_late':'total_vol'})

# %%
# per date
vol_per_date
# Out:
#                           total_vol
# arrival_real_date_planed
# 2017-10-01                       30
# 2017-10-02                       28
# 2017-10-03                       30
# 2017-10-04                       30
# 2017-10-05                       30
# ...                             ...
# 2020-04-03                        2
# 2020-04-06                        2
# 2020-04-11                        2
# 2020-04-16                        2
# 2020-04-18                        2
#
# [535 rows x 1 columns]

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 7)})

# %%
vol_per_date_late['is_late'].plot(linewidth=0.5,color='red',legend='Vol en retard')
vol_per_date['total_vol'].plot(linewidth=0.5,color='blue',legend='Total vols')

# %% [markdown]
# ## Comme le montre le graphe, nous pouvons remarquer pour la periode de Oct 2017 jusqu'a Avril 2018, le nombre de retard et le nombre de vol ont la meme tendance, ils augmentent.
# ##

# %%
df_final_review_['Vol'].nunique()
# Out:
# 364

# %%
Vol = 'B61509 JBU1509 JetBlue Airways (B6 / JBU)'

# %%
Vol.split(' ')
# Out:
# ['B61509', 'JBU1509', 'JetBlue', 'Airways', '(B6', '/', 'JBU)']

# %%
Vol1 = 'S613 Flag of Haiti Sunrise Airways (S6 / KSZ)'

# %%
Vol1.split(' ')
# Out:
# ['S613', 'Flag', 'of', 'Haiti', 'Sunrise', 'Airways', '(S6', '/', 'KSZ)']

# %%
Vol2 = 'AA1158 AAL1158 American Airlines (AA / AAL)'

# %%
Vol2.split(' ')
# Out:
# ['AA1158', 'AAL1158', 'American', 'Airlines', '(AA', '/', 'AAL)']

# %%
def select_compagnies(x):
    compagnies = ['American Airlines','Haiti Sunrise Airways','JetBlue Airways','Air Century', 'Spirit Airlines','Air France',' Air Caraïbes',' Delta Air Lines','Cubana','Amerijet International','InterCaribbean Airways','Air Transat','Copa Airlines','IBC Airways','Winair']
    for comp  in compagnies:
        if comp in str(x):
            return comp
            
            
    return 'other'

# %%
select_compagnies('S613 Flag of Haiti Sunrise Airways (S6 / KSZ)')
# Out:
# 'Haiti Sunrise Airways'

# %%
df_final_review_['compagny'] = df_final_review_['Vol'].apply(lambda x: select_compagnies(x) )
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_final_review_[df_final_review_.compagny == '']
# Out:
# Empty DataFrame
# Columns: [Vol, De, arrival_real_date_planed, arrival_real_date_time_planed, arrival_real_date_time, year, month, hour, weekday, quarter, delay_in_minutes, duration_in_minutes, is_late, compagny]
# Index: []

# %%
#
def group_dataset(dataset,group_columns=[],col_agg=None,colunm_name =None):
    df1 = dataset.groupby(group_columns)[col_agg].count().to_frame().rename(columns={col_agg:colunm_name}).reset_index().sort_values(by=colunm_name,ascending=False)
    df2 = dataset[dataset[col_agg] ==1].groupby(group_columns)[col_agg].count().to_frame().reset_index().sort_values(by=col_agg,ascending=False)
    df3 = dataset[dataset[col_agg] ==0].groupby(group_columns)[col_agg].count().to_frame().rename(columns={col_agg:'not_late'}).reset_index().sort_values(by='not_late',ascending=False)
    df=pd.merge(df1,df2,how='left',on=group_columns)
    df1=pd.merge(df,df3,how='left',on=group_columns)
    df1['% late'] = np.round((df1['is_late']/df1['Total'])*100,2)
    df1.fillna(0,inplace=True)
    df1.sort_values(by='Total',inplace=True)
    return df1

# %%
# Tableau permettant de voir le nombre de retard, le pourcentage de retard,
df=group_dataset(df_final_review_,['compagny'],'is_late','Total')

# %%
df
# Out:
#                   compagny  Total  is_late  not_late  % late
# 15                  Cubana    109       14        95   12.84
# 14                  Winair    134       27       107   20.15
# 13             Air Transat    165      110        55   66.67
# 12            Air Caraïbes    194      141        53   72.68
# 11             IBC Airways    215       78       137   36.28
# 10  InterCaribbean Airways    256       76       180   29.69
# 9   Amerijet International    267       97       170   36.33
# 8            Copa Airlines    393       64       329   16.28
# 7              Air Century    626        8       618    1.28
# 6          Delta Air Lines    646      191       455   29.57
# 5          Spirit Airlines    827      180       647   21.77
# 4                    other    964      474       490   49.17
# 3               Air France   1002      375       627   37.43
# 2    Haiti Sunrise Airways   1935       81      1854    4.19
# 1        American Airlines   3262      802      2460   24.59
# 0          JetBlue Airways   4017     1816      2201   45.21

# %%
sns.barplot(x='Total', y='compagny', data=df)

# %%
#Graphe representant le retard des vols par compagnie
sns.barplot(x='% late', y='compagny', data=df)

# %%
# by day and year
def group_dataset2(column_name ='weekday'):
    df1=df_final_review_.groupby(['year',column_name]).is_late.count().to_frame().reset_index()
    df1= df1.groupby([column_name]).is_late.mean().reset_index().sort_values('is_late').rename(columns={'is_late':'Total'})
    df2=df_final_review_[df_final_review_.is_late==1].groupby(['year',column_name]).is_late.count().to_frame().reset_index()
    df2 =df2.groupby([column_name]).is_late.mean().reset_index().sort_values('is_late')
    df3=df_final_review_[df_final_review_.is_late==0].groupby(['year',column_name]).is_late.count().to_frame().reset_index()
    df3=df3.groupby([column_name]).is_late.mean().reset_index().sort_values('is_late').rename(columns={'is_late':'not_late'})
    df=pd.merge(df1,df2,how='left',on=column_name)
    df4=pd.merge(df,df3,how='left',on=column_name)
    df4['% late'] = np.round((df4['is_late']/df1['Total'])*100,2)
    df4.fillna(0,inplace=True)
    df4.sort_values(by='Total',inplace=True)
    return df4

# %%
df4= group_dataset2('hour')

# %%
df4
# Out:
#     hour       Total     is_late    not_late    % late
# 0     22    1.000000    0.000000    1.000000      0.00
# 1      0    2.000000    2.000000    0.000000    100.00
# 2      6    2.000000    2.000000    2.000000      0.86
# 3     21    2.666667    1.000000    2.000000      0.16
# 4     23    7.000000    0.000000    7.000000      0.00
# 5     19   10.666667    2.500000    9.000000      2.42
# 6     20   13.666667    1.000000   13.333333      0.22
# 7     10  103.250000   50.500000   78.000000     10.65
# 8     18  154.000000   64.500000   89.500000     17.39
# 9     16  183.250000   74.000000  127.750000     24.54
# 10    17  203.750000   54.666667  162.750000     25.73
# 11    15  212.500000  102.500000  110.000000     55.93
# 12     7  232.666667  152.666667   80.000000     74.93
# 13    14  301.500000  118.250000  183.250000     76.79
# 14    13  371.000000  159.666667  251.250000   1496.88
# 15    11  445.750000  144.750000  301.000000   1059.15
# 16    12  474.000000  142.000000  332.000000   5325.00
# 17     9  494.250000  110.250000  384.000000  11025.00
# 18     8  611.500000   92.250000  519.250000   1317.86

# %%
#Graphe representant le retard des vols par compagnie
df4.sort_values(by='Total',inplace=True)
sns.barplot(x='hour', y='Total', data=df4)

# %%
#Graphe representant le retard des vols par compagnie
df4.sort_values(by='% late',inplace=True)
sns.barplot(x='hour', y='% late', data=df4)

# %%
df4= group_dataset2('month')
#Graphe representant le retard des vols par compagnie
df4.sort_values(by='Total',inplace=True)
sns.barplot(x='month', y='Total', data=df4)

# %%
sns.barplot(x='month', y='% late', data=df4)

# %%
df4= group_dataset2('quarter')
#Graphe representant le retard des vols par compagnie
df4.sort_values(by='Total',inplace=True)
sns.barplot(x='quarter', y='Total', data=df4)

# %%
df4= group_dataset2('quarter')
#Graphe representant le retard des vols par compagnie
df4.sort_values(by='Total',inplace=True)
sns.barplot(x='quarter', y='% late', data=df4)

# %%
df_final_review_[['delay_in_minutes']].boxplot()

# %%
df_final_review_[['duration_in_minutes']].boxplot()

# %%
df_final_review_.describe()
# Out:
#                year         month          hour       weekday       quarter  \
# count  15012.000000  15012.000000  15012.000000  15012.000000  15012.000000
# mean    2018.420264      6.785105     11.733413      2.959166      2.620171
# std        0.649354      2.381881      3.173771      1.996432      0.906685
# min     2017.000000      3.000000      0.000000      0.000000      1.000000
# 25%     2018.000000      5.000000      9.000000      1.000000      2.000000
# 50%     2018.000000      7.000000     12.000000      3.000000      3.000000
# 75%     2019.000000      9.000000     14.000000      5.000000      3.000000
# max     2020.000000     11.000000     23.000000      6.000000      4.000000
#
#        delay_in_minutes  duration_in_minutes       is_late
# count      15012.000000         15012.000000  15012.000000
# mean           4.277911           124.969158      0.302025
# std           44.006946            98.196476      0.459151
# min        -1042.000000             1.000000      0.000000
# 25%          -12.000000            91.000000      0.000000
# 50%            0.000000           101.000000      0.000000
# 75%            5.000000           142.000000      1.000000
# max          920.000000          1438.000000      1.000000

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
g = sns.regplot(df_final_review_['duration_in_minutes'],df_final_review_['delay_in_minutes'])

# %%
df_final_review_.corr()['is_late']
# Out:
# year                  -0.048368
# month                 -0.003817
# hour                   0.058273
# weekday                0.043905
# quarter               -0.008618
# delay_in_minutes       0.513471
# duration_in_minutes    0.191193
# is_late                1.000000
# Name: is_late, dtype: float64

# %%
df_final_review_

# %% [markdown]
# ## Modelling <a name="modelling"></a>

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>
